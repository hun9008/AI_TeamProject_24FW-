# %%
# !pip install wget torchinfo
# !wget -O NCT-CRC-HE-100K.zip https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# !unzip -qq NCT-CRC-HE-100K.zip -d train
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=916089c101e194fd307d8b9a81146bd0eac2239a8d378754a5187779ea777bf5
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget, torchinfo
# Successfully installed torchinfo-1.8.0 wget-3.2
# --2025-02-05 03:02:13--  https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/1214456/files/NCT-CRC-HE-100K.zip [following]
# --2025-02-05 03:02:14--  https://zenodo.org/records/1214456/files/NCT-CRC-HE-100K.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11690284003 (11G) [application/octet-stream]
# Saving to: ‘NCT-CRC-HE-100K.zip’
#
# NCT-CRC-HE-100K.zip 100%[===================>]  10.89G  18.3MB/s    in 11m 16s
#
# 2025-02-05 03:13:30 (16.5 MB/s) - ‘NCT-CRC-HE-100K.zip’ saved [11690284003/11690284003]

# %%
import timm
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, ConcatDataset
import numpy as np
from tqdm import tqdm

import itertools
from torchinfo import summary

# %%
class ConvNorm(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=2, padding=1):
        super(ConvNorm, self).__init__()
        self.linear = nn.Conv2d(
            in_channels, out_channels, kernel_size=kernel_size,
            stride=stride, padding=padding, bias=False
        )
        self.bn = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.linear(x)
        x = self.bn(x)
        return x

# %%
class Stem16(nn.Module):
    def __init__(self):
        super(Stem16, self).__init__()
        self.conv1 = ConvNorm(3, 32)
        self.act1 = nn.Hardswish()
        self.conv2 = ConvNorm(32, 64)
        self.act2 = nn.Hardswish()
        self.conv3 = ConvNorm(64, 128)
        self.act3 = nn.Hardswish()
        self.conv4 = ConvNorm(128, 256)

    def forward(self, x):
        x = self.act1(self.conv1(x))
        x = self.act2(self.conv2(x))
        x = self.act3(self.conv3(x))
        x = self.conv4(x)
        return x

# %%
class LinearNorm(nn.Module):
    def __init__(self, in_features, out_features):
        super(LinearNorm, self).__init__()
        self.linear = nn.Linear(in_features, out_features, bias=False)
        self.bn = nn.BatchNorm1d(out_features)

    def forward(self, x):

        if x.dim() == 3:
            B, N, C = x.shape
            x = x.reshape(B * N, C)
            x = self.bn(self.linear(x))
            x = x.reshape(B, N, -1)
        else:
            x = self.bn(self.linear(x))
        return x

# %%
class Attention(nn.Module):
    def __init__(self, dim, num_heads, attn_ratio=2):
        super(Attention, self).__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5
        inner_dim = head_dim * num_heads * 3
        self.qkv = LinearNorm(dim, inner_dim)

        self.proj = nn.Sequential(
            nn.Hardswish(),
            LinearNorm(dim, dim)
        )

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.view(B, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        return self.proj(x)

# %%
class LevitMlp(nn.Module):
    def __init__(self, in_features, hidden_features, out_features):
        super(LevitMlp, self).__init__()
        self.ln1 = LinearNorm(in_features, hidden_features)
        self.act = nn.Hardswish()
        self.drop = nn.Dropout(p=0.5, inplace=False)#dropout 적용
        self.ln2 = LinearNorm(hidden_features, out_features)

    def forward(self, x):
        x = self.ln1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.ln2(x)
        return x

# %%
class LevitBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2):
        super(LevitBlock, self).__init__()
        self.attn = Attention(dim, num_heads)
        self.drop_path1 = nn.Identity()
        self.mlp = LevitMlp(dim, dim * mlp_ratio, dim)
        self.drop_path2 = nn.Identity()

    def forward(self, x):
        x = x + self.drop_path1(self.attn(x))
        x = x + self.drop_path2(self.mlp(x))
        return x

# %%
class CNNDownsample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(CNNDownsample, self).__init__()
        self.out_channels = out_channels
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)
        self.act = nn.Hardswish()

    def forward(self, x):
        # print(x.shape)
        B, N, C = x.shape # (B, N, C)  N=H*W (16 * 16 = 196)
        H = int(np.sqrt(N))
        x = x.view(B, H, H, C).permute(0, 3, 1, 2)
        x = self.conv(x)
        x = self.act(x)
        x = x.permute(0, 2, 3, 1).view(B, -1, self.out_channels)
        return x

# %%
class LevitStage(nn.Module):
    def __init__(self, dim, out_dim, num_heads, num_blocks, downsample=True):
        super(LevitStage, self).__init__()
        self.downsample = CNNDownsample(dim, out_dim) if downsample else nn.Identity()
        self.blocks = nn.Sequential(*[LevitBlock(out_dim, num_heads) for _ in range(num_blocks)])

    def forward(self, x):
        x = self.downsample(x)
        x = self.blocks(x)
        return x

# %%
class ConvLevitStage(nn.Module):
    def __init__(self, in_channels, out_channels, num_blocks, kernel_size, stride, padding):
        super(ConvLevitStage, self).__init__()
        self.layers = nn.Sequential(
            *[nn.Conv2d(in_channels if i == 0 else out_channels, out_channels, kernel_size, stride, padding)
              for i in range(num_blocks)],
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.layers(x)

# %%
class NormLinear(nn.Module):
    def __init__(self, in_features, out_features, dropout_prob=0.5):#drop_out_0.5 적용
        super(NormLinear, self).__init__()
        self.bn = nn.BatchNorm1d(in_features)
        self.drop = nn.Dropout(p=dropout_prob, inplace=False)
        self.linear = nn.Linear(in_features, out_features, bias=True)

    def forward(self, x):
        x = self.bn(x)
        x = self.drop(x)
        x = self.linear(x)
        return x

# %%
class LevitDistilled(nn.Module):
    def __init__(self, num_classes=9):
        super(LevitDistilled, self).__init__()

        self.stem = Stem16()

        self.stage1 = LevitStage(dim=256, out_dim=256, num_heads=4, num_blocks=5, downsample=False) # block 수 적용
        self.stage2 = LevitStage(dim=256, out_dim=384, num_heads=6, num_blocks=5, downsample=True)

        self.conv1x1 = nn.Sequential(
            nn.Conv2d(384, 512, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        self.head = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)
        self.head_dist = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)

    def forward(self, x):
        x = self.stem(x)

        B, C, H, W = x.shape
        x = x.view(B, C, -1).transpose(1, 2)
        x = self.stage1(x)
        x = self.stage2(x)

        H = W = int(x.shape[1]**0.5)
        x = x.transpose(1, 2).view(B, 384, H, W)

        x = self.conv1x1(x)

        x = torch.mean(x, dim=(2, 3))
        out = self.head(x)
        out_dist = self.head_dist(x)
        return out

# %%
model = LevitDistilled()
print(model)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

batch_size = 32
learning_rate = 5e-4
decay_rate = 1e-6
num_epochs = 30
# Out:
# LevitDistilled(
#   (stem): Stem16(
#     (conv1): ConvNorm(
#       (linear): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act1): Hardswish()
#     (conv2): ConvNorm(
#       (linear): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act2): Hardswish()
#     (conv3): ConvNorm(
#       (linear): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act3): Hardswish()
#     (conv4): ConvNorm(
#       (linear): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stage1): LevitStage(
#     (downsample): Identity()
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (2): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (3): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (4): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (stage2): LevitStage(
#     (downsample): CNNDownsample(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): Hardswish()
#     )
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (2): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (3): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (4): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (conv1x1): Sequential(
#     (0): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (head): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (head_dist): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
print(summary(model, input_size=(32, 3, 224, 224), verbose=2))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilled                                          [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                                        ├─864
# │    └─conv1.bn.weight                                                            ├─32
# │    └─conv1.bn.bias                                                              ├─32
# │    └─conv2.linear.weight                                                        ├─18,432
# │    └─conv2.bn.weight                                                            ├─64
# │    └─conv2.bn.bias                                                              ├─64
# │    └─conv3.linear.weight                                                        ├─73,728
# │    └─conv3.bn.weight                                                            ├─128
# │    └─conv3.bn.bias                                                              ├─128
# │    └─conv4.linear.weight                                                        ├─294,912
# │    └─conv4.bn.weight                                                            ├─256
# │    └─conv4.bn.bias                                                              └─256
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─linear.weight                                                         ├─864
# │    │    └─bn.weight                                                             ├─32
# │    │    └─bn.bias                                                               └─32
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    │    └─weight                                                           └─864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    │    │    └─weight                                                           ├─32
# │    │    │    └─bias                                                             └─32
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─linear.weight                                                         ├─18,432
# │    │    └─bn.weight                                                             ├─64
# │    │    └─bn.bias                                                               └─64
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                                           └─18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    │    │    └─weight                                                           ├─64
# │    │    │    └─bias                                                             └─64
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─linear.weight                                                         ├─73,728
# │    │    └─bn.weight                                                             ├─128
# │    │    └─bn.bias                                                               └─128
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                                           └─73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    │    │    └─weight                                                           ├─128
# │    │    │    └─bias                                                             └─128
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─linear.weight                                                         ├─294,912
# │    │    └─bn.weight                                                             ├─256
# │    │    └─bn.bias                                                               └─256
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                                           └─294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# │    │    │    └─weight                                                           ├─256
# │    │    │    └─bias                                                             └─256
# ├─LevitStage: 1-2                                       [32, 196, 256]            --
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.2.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.2.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.2.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.2.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.2.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.2.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.2.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.2.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.2.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.2.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.2.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.2.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.3.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.3.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.3.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.3.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.3.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.3.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.3.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.3.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.3.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.3.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.3.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.3.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.4.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.4.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.4.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.4.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.4.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.4.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.4.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.4.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.4.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.4.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.4.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.4.mlp.ln2.bn.bias                                                   └─256
# │    └─Identity: 2-8                                    [32, 196, 256]            --
# │    └─Sequential: 2-9                                  [32, 196, 256]            --
# │    │    └─0.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─0.attn.qkv.bn.weight                                                  ├─768
# │    │    └─0.attn.qkv.bn.bias                                                    ├─768
# │    │    └─0.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─0.attn.proj.1.bn.weight                                               ├─256
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─0.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─0.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─1.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─1.attn.qkv.bn.weight                                                  ├─768
# │    │    └─1.attn.qkv.bn.bias                                                    ├─768
# │    │    └─1.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─1.attn.proj.1.bn.weight                                               ├─256
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─1.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─1.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─1.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─2.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─2.attn.qkv.bn.weight                                                  ├─768
# │    │    └─2.attn.qkv.bn.bias                                                    ├─768
# │    │    └─2.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─2.attn.proj.1.bn.weight                                               ├─256
# │    │    └─2.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─2.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─2.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─2.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─2.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─2.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─2.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─3.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─3.attn.qkv.bn.weight                                                  ├─768
# │    │    └─3.attn.qkv.bn.bias                                                    ├─768
# │    │    └─3.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─3.attn.proj.1.bn.weight                                               ├─256
# │    │    └─3.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─3.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─3.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─3.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─3.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─3.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─3.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─4.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─4.attn.qkv.bn.weight                                                  ├─768
# │    │    └─4.attn.qkv.bn.bias                                                    ├─768
# │    │    └─4.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─4.attn.proj.1.bn.weight                                               ├─256
# │    │    └─4.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─4.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─4.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─4.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─4.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─4.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─4.mlp.ln2.bn.bias                                                     └─256
# │    │    └─LevitBlock: 3-9                             [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# │    │    └─LevitBlock: 3-10                            [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# │    │    └─LevitBlock: 3-11                            [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# │    │    └─LevitBlock: 3-12                            [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# │    │    └─LevitBlock: 3-13                            [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# ├─LevitStage: 1-3                                       [32, 49, 384]             --
# │    └─downsample.conv.weight                                                     ├─884,736
# │    └─downsample.conv.bias                                                       ├─384
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.2.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.2.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.2.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.2.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.2.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.2.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.2.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.2.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.2.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.2.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.2.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.2.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.3.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.3.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.3.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.3.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.3.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.3.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.3.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.3.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.3.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.3.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.3.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.3.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.4.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.4.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.4.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.4.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.4.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.4.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.4.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.4.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.4.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.4.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.4.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.4.mlp.ln2.bn.bias                                                   └─384
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─conv.weight                                                           ├─884,736
# │    │    └─conv.bias                                                             └─384
# │    │    └─Conv2d: 3-14                                [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                                           ├─884,736
# │    │    │    └─bias                                                             └─384
# │    │    └─Hardswish: 3-15                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 [32, 49, 384]             --
# │    │    └─0.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─0.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─0.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─0.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─0.attn.proj.1.bn.weight                                               ├─384
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─0.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─0.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─1.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─1.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─1.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─1.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─1.attn.proj.1.bn.weight                                               ├─384
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─1.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─1.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─1.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─2.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─2.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─2.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─2.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─2.attn.proj.1.bn.weight                                               ├─384
# │    │    └─2.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─2.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─2.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─2.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─2.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─3.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─3.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─3.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─3.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─3.attn.proj.1.bn.weight                                               ├─384
# │    │    └─3.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─3.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─3.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─3.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─3.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─4.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─4.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─4.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─4.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─4.attn.proj.1.bn.weight                                               ├─384
# │    │    └─4.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─4.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─4.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─4.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─4.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─4.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─4.mlp.ln2.bn.bias                                                     └─384
# │    │    └─LevitBlock: 3-16                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-17                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-18                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-19                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-20                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─0.weight                                                                   ├─196,608
# │    └─0.bias                                                                     ├─512
# │    └─1.weight                                                                   ├─512
# │    └─1.bias                                                                     └─512
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    │    └─weight                                                                ├─196,608
# │    │    └─bias                                                                  └─512
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# =========================================================================================================
# Total params: 10,047,922
# Trainable params: 10,047,922
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 33.44
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 1639.62
# Params size (MB): 40.19
# Estimated Total Size (MB): 1699.08
# =========================================================================================================
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilled                                          [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                                        ├─864
# │    └─conv1.bn.weight                                                            ├─32
# │    └─conv1.bn.bias                                                              ├─32
# │    └─conv2.linear.weight                                                        ├─18,432
# │    └─conv2.bn.weight                                                            ├─64
# │    └─conv2.bn.bias                                                              ├─64
# │    └─conv3.linear.weight                                                        ├─73,728
# │    └─conv3.bn.weight                                                            ├─128
# │    └─conv3.bn.bias                                                              ├─128
# │    └─conv4.linear.weight                                                        ├─294,912
# │    └─conv4.bn.weight                                                            ├─256
# │    └─conv4.bn.bias                                                              └─256
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─linear.weight                                                         ├─864
# │    │    └─bn.weight                                                             ├─32
# │    │    └─bn.bias                                                               └─32
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    │    └─weight                                                           └─864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    │    │    └─weight                                                           ├─32
# │    │    │    └─bias                                                             └─32
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─linear.weight                                                         ├─18,432
# │    │    └─bn.weight                                                             ├─64
# │    │    └─bn.bias                                                               └─64
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                                           └─18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    │    │    └─weight                                                           ├─64
# │    │    │    └─bias                                                             └─64
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─linear.weight                                                         ├─73,728
# │    │    └─bn.weight                                                             ├─128
# │    │    └─bn.bias                                                               └─128
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                                           └─73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    │    │    └─weight                                                           ├─128
# │    │    │    └─bias                                                             └─128
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─linear.weight                                                         ├─294,912
# │    │    └─bn.weight                                                             ├─256
# │    │    └─bn.bias                                                               └─256
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                                           └─294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# │    │    │    └─weight                                                           ├─256
# │    │    │    └─bias                                                             └─256
# ...
# │    └─blocks.4.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.4.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.4.mlp.ln2.bn.bias                                                   └─384
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─conv.weight                                                           ├─884,736
# │    │    └─conv.bias                                                             └─384
# │    │    └─Conv2d: 3-14                                [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                                           ├─884,736
# │    │    │    └─bias                                                             └─384
# │    │    └─Hardswish: 3-15                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 [32, 49, 384]             --
# │    │    └─0.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─0.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─0.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─0.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─0.attn.proj.1.bn.weight                                               ├─384
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─0.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─0.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─1.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─1.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─1.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─1.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─1.attn.proj.1.bn.weight                                               ├─384
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─1.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─1.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─1.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─2.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─2.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─2.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─2.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─2.attn.proj.1.bn.weight                                               ├─384
# │    │    └─2.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─2.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─2.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─2.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─2.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─2.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─3.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─3.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─3.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─3.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─3.attn.proj.1.bn.weight                                               ├─384
# │    │    └─3.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─3.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─3.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─3.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─3.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─3.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─4.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─4.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─4.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─4.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─4.attn.proj.1.bn.weight                                               ├─384
# │    │    └─4.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─4.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─4.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─4.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─4.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─4.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─4.mlp.ln2.bn.bias                                                     └─384
# │    │    └─LevitBlock: 3-16                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-17                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-18                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-19                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-20                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─0.weight                                                                   ├─196,608
# │    └─0.bias                                                                     ├─512
# │    └─1.weight                                                                   ├─512
# │    └─1.bias                                                                     └─512
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    │    └─weight                                                                ├─196,608
# │    │    └─bias                                                                  └─512
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# =========================================================================================================
# Total params: 10,047,922
# Trainable params: 10,047,922
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 33.44
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 1639.62
# Params size (MB): 40.19
# Estimated Total Size (MB): 1699.08
# =========================================================================================================

# %%
import torch
from torch.utils.data import DataLoader, random_split, Dataset
from torchvision import datasets, transforms

# 데이터셋 경로
dataset_dir = './train/NCT-CRC-HE-100K'

# 변환 설정
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# 데이터셋 로드
full_dataset = datasets.ImageFolder(root=dataset_dir, transform=transform)

# 데이터셋 길이
total_size = len(full_dataset)
train_size = int(total_size * 0.7)
val_size = int(total_size * 0.15)
test_size = total_size - train_size - val_size  # 나머지를 테스트셋에 할당

# 데이터셋 나누기
train_set, val_set, test_set = random_split(full_dataset, [train_size, val_size, test_size])

# %%
batch_size = 32
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

print(f"Train set size: {len(train_set)}")
print(f"Validation set size: {len(val_set)}")
print(f"Test set size: {len(test_set)}")
# Out:
# Train set size: 70000
# Validation set size: 15000
# Test set size: 15000

# %%
# Show one example per class from the training dataset
import matplotlib.pyplot as plt

# Prepare a dictionary to store one example per class
class_examples = {}
for images, labels in train_loader:
    for img, label in zip(images, labels):
        label = label.item()
        if label not in class_examples:
            class_examples[label] = img
        # Stop if we already have one example for each class
        if len(class_examples) == len(train_set.dataset.classes):
            break
    if len(class_examples) == len(train_set.dataset.classes):
        break

# Display the images and their labels
figure = plt.figure(figsize=(8, 8))
cols = 3  # You can adjust the number of columns as needed
rows = (len(train_set.dataset.classes) + cols - 1) // cols  # Calculate required rows
for i, (label, img) in enumerate(class_examples.items(), start=1):
    figure.add_subplot(rows, cols, i)
    plt.title(train_set.dataset.classes[label])
    plt.axis("off")
    plt.imshow(img.permute(1, 2, 0).numpy())  # Convert tensor to numpy for display
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9131652..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9306722..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5105042..2.6051416].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7030813..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5805322..2.622571].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0007002..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9481792..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7030813..2.64].

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay = decay_rate)

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in tqdm(train_loader, desc="Training"):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {accuracy:.2f}%")
    train_losses.append(epoch_loss)
    train_accuracies.append(accuracy)

# %%
def evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

# %%
def measure_inference_time(model, data_loader, device):
    model.eval()
    times = []

    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            start_time = torch.cuda.Event(enable_timing=True)
            end_time = torch.cuda.Event(enable_timing=True)

            start_time.record()
            _ = model(inputs)  # inference 수행
            end_time.record()

            # 시간 측정
            torch.cuda.synchronize()  # CUDA에서 모든 커널이 완료될 때까지 대기
            elapsed_time = start_time.elapsed_time(end_time)  # 밀리초 단위로 반환
            times.append(elapsed_time)

    # 통계량 계산
    times_np = np.array(times)
    total_inferences = len(times_np)
    avg_time = np.mean(times_np)
    std_dev = np.std(times_np)
    max_time = np.max(times_np)
    min_time = np.min(times_np)

    # 결과 출력
    print(f"Inference Time Measurement Results:")
    print(f"Total Inferences: {total_inferences}")
    print(f"Average Time: {avg_time:.2f} ms")
    print(f"Standard Deviation: {std_dev:.2f} ms")
    print(f"Maximum Time: {max_time:.2f} ms")
    print(f"Minimum Time: {min_time:.2f} ms")

    return times

# %%
for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    train(model, train_loader, criterion, optimizer, device)
    evaluate(model, val_loader, criterion, device, phase="Validation")
# Out:
# Epoch 1/30
# Training: 100%|██████████| 2188/2188 [03:01<00:00, 12.05it/s]
# Train Loss: 0.6022, Train Accuracy: 78.40%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.70it/s]
# Validation Loss: 0.3678, Validation Accuracy: 86.99%
#
# Epoch 2/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.13it/s]
# Train Loss: 0.3612, Train Accuracy: 87.46%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.46it/s]
# Validation Loss: 0.2193, Validation Accuracy: 92.65%
#
# Epoch 3/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.19it/s]
# Train Loss: 0.2553, Train Accuracy: 91.27%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.79it/s]
# Validation Loss: 0.1900, Validation Accuracy: 93.52%
#
# Epoch 4/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.21it/s]
# Train Loss: 0.1994, Train Accuracy: 93.16%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.93it/s]
# Validation Loss: 0.2427, Validation Accuracy: 92.03%
#
# Epoch 5/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.17it/s]
# Train Loss: 0.1681, Train Accuracy: 94.23%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.89it/s]
# Validation Loss: 0.2481, Validation Accuracy: 91.65%
#
# Epoch 6/30
# Training: 100%|██████████| 2188/2188 [02:58<00:00, 12.23it/s]
# Train Loss: 0.1372, Train Accuracy: 95.33%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.85it/s]
# Validation Loss: 0.2726, Validation Accuracy: 91.44%
#
# Epoch 7/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.21it/s]
# Train Loss: 0.1126, Train Accuracy: 96.12%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.91it/s]
# Validation Loss: 0.1321, Validation Accuracy: 95.55%
#
# Epoch 8/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.18it/s]
# Train Loss: 0.0947, Train Accuracy: 96.79%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.91it/s]
# Validation Loss: 0.1451, Validation Accuracy: 95.14%
#
# Epoch 9/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.20it/s]
# Train Loss: 0.0780, Train Accuracy: 97.37%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.88it/s]
# Validation Loss: 0.1264, Validation Accuracy: 95.79%
#
# Epoch 10/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.15it/s]
# Train Loss: 0.0664, Train Accuracy: 97.82%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.82it/s]
# Validation Loss: 0.1483, Validation Accuracy: 95.11%
#
# Epoch 11/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.17it/s]
# Train Loss: 0.0554, Train Accuracy: 98.14%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.64it/s]
# Validation Loss: 0.0633, Validation Accuracy: 97.95%
#
# Epoch 12/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.19it/s]
# Train Loss: 0.0494, Train Accuracy: 98.36%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.84it/s]
# Validation Loss: 0.0477, Validation Accuracy: 98.45%
#
# Epoch 13/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.19it/s]
# Train Loss: 0.0434, Train Accuracy: 98.52%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.97it/s]
# Validation Loss: 0.0609, Validation Accuracy: 98.07%
#
# Epoch 14/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.21it/s]
# Train Loss: 0.0383, Train Accuracy: 98.68%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.87it/s]
# Validation Loss: 0.0589, Validation Accuracy: 98.22%
#
# Epoch 15/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.20it/s]
# Train Loss: 0.0321, Train Accuracy: 98.91%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.83it/s]
# Validation Loss: 0.0640, Validation Accuracy: 98.10%
#
# Epoch 16/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.19it/s]
# Train Loss: 0.0319, Train Accuracy: 98.92%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.89it/s]
# Validation Loss: 0.0418, Validation Accuracy: 98.61%
#
# Epoch 17/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.20it/s]
# Train Loss: 0.0284, Train Accuracy: 99.04%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.89it/s]
# Validation Loss: 0.0982, Validation Accuracy: 97.24%
#
# Epoch 18/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.19it/s]
# Train Loss: 0.0275, Train Accuracy: 99.07%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.94it/s]
# Validation Loss: 0.0413, Validation Accuracy: 98.71%
#
# Epoch 19/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.18it/s]
# Train Loss: 0.0238, Train Accuracy: 99.18%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.90it/s]
# Validation Loss: 0.0581, Validation Accuracy: 98.20%
#
# Epoch 20/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.20it/s]
# Train Loss: 0.0236, Train Accuracy: 99.20%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.73it/s]
# Validation Loss: 0.0802, Validation Accuracy: 97.62%
#
# Epoch 21/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.14it/s]
# Train Loss: 0.0200, Train Accuracy: 99.33%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.82it/s]
# Validation Loss: 0.0420, Validation Accuracy: 98.77%
#
# Epoch 22/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.15it/s]
# Train Loss: 0.0211, Train Accuracy: 99.25%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.58it/s]
# Validation Loss: 0.0615, Validation Accuracy: 98.37%
#
# Epoch 23/30
# Training: 100%|██████████| 2188/2188 [02:59<00:00, 12.16it/s]
# Train Loss: 0.0170, Train Accuracy: 99.41%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.73it/s]
# Validation Loss: 0.0505, Validation Accuracy: 98.51%
#
# Epoch 24/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.11it/s]
# Train Loss: 0.0181, Train Accuracy: 99.37%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.81it/s]
# Validation Loss: 0.0386, Validation Accuracy: 98.84%
#
# Epoch 25/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.13it/s]
# Train Loss: 0.0174, Train Accuracy: 99.42%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.77it/s]
# Validation Loss: 0.0502, Validation Accuracy: 98.47%
#
# Epoch 26/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.14it/s]
# Train Loss: 0.0178, Train Accuracy: 99.40%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.59it/s]
# Validation Loss: 0.0695, Validation Accuracy: 98.11%
#
# Epoch 27/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.10it/s]
# Train Loss: 0.0166, Train Accuracy: 99.43%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.67it/s]
# Validation Loss: 0.0426, Validation Accuracy: 98.75%
#
# Epoch 28/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.11it/s]
# Train Loss: 0.0164, Train Accuracy: 99.45%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.73it/s]
# Validation Loss: 0.0424, Validation Accuracy: 98.85%
#
# Epoch 29/30
# Training: 100%|██████████| 2188/2188 [03:01<00:00, 12.08it/s]
# Train Loss: 0.0141, Train Accuracy: 99.52%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.79it/s]
# Validation Loss: 0.0442, Validation Accuracy: 98.79%
#
# Epoch 30/30
# Training: 100%|██████████| 2188/2188 [03:00<00:00, 12.13it/s]
# Train Loss: 0.0157, Train Accuracy: 99.49%
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.68it/s]
# Validation Loss: 0.0486, Validation Accuracy: 98.59%

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 5))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label="Train Accuracy")
plt.plot(epochs, val_accuracies, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
times = measure_inference_time(model, test_loader, device)
# Out:
# Inference Time Measurement Results:
# Total Inferences: 469
# Average Time: 11.51 ms
# Standard Deviation: 0.47 ms
# Maximum Time: 14.75 ms
# Minimum Time: 10.87 ms

# %%
evaluate(model, test_loader, criterion, device)
# Out:
# Validation: 100%|██████████| 469/469 [00:26<00:00, 17.57it/s]
# Validation Loss: 0.0501, Validation Accuracy: 98.51%

# %%
from torch import profiler

dummy_input = torch.randn(32, 3, 224, 224).cuda()

# Profiling inference
with profiler.profile(
    activities=[
       profiler.ProfilerActivity.CPU,
        profiler.ProfilerActivity.CUDA,  # Include if using GPU
    ],
    on_trace_ready=profiler.tensorboard_trace_handler("./logs"),  # Optional logging
    record_shapes=True,
    with_stack=True
) as prof:
    with torch.no_grad():
        model(dummy_input)


# Print results
print(prof.key_averages().table(sort_by="cuda_time_total" if torch.cuda.is_available() else "cpu_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::matmul         2.29%     550.762us        23.21%       5.586ms      93.094us       0.000us         0.00%       6.322ms     105.361us            60
#                                            aten::linear         0.86%     205.931us        14.89%       3.584ms      85.339us       0.000us         0.00%       4.516ms     107.535us            42
#                                                aten::mm         5.66%       1.361ms        11.43%       2.750ms      68.747us       4.493ms        46.66%       4.493ms     112.319us            40
#                                  ampere_sgemm_32x128_tn         0.00%       0.000us         0.00%       0.000us       0.000us       1.689ms        17.54%       1.689ms     168.861us            10
#                                               aten::bmm         2.39%     576.019us         3.14%     754.839us      37.742us       1.418ms        14.73%       1.418ms      70.901us            20
#                                 ampere_sgemm_128x128_nn         0.00%       0.000us         0.00%       0.000us       0.000us       1.234ms        12.82%       1.234ms     123.408us            10
#                                        aten::batch_norm         1.06%     255.668us        36.62%       8.811ms     187.469us       0.000us         0.00%       1.037ms      22.070us            47
#                            aten::_batch_norm_impl_index         2.12%     509.044us        35.55%       8.555ms     182.030us       0.000us         0.00%       1.037ms      22.070us            47
#                                             aten::copy_         4.01%     964.511us         9.63%       2.318ms      22.722us       1.024ms        10.64%       1.024ms      10.042us           102
#                                  ampere_sgemm_128x64_tn         0.00%       0.000us         0.00%       0.000us       0.000us     966.401us        10.04%     966.401us      96.640us            10
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 24.064ms
# Self CUDA time total: 9.629ms

# %%
save_path = "HoViT44_NCT_CRC_HE.pth"
torch.save(model.state_dict(), save_path)
print(f"Model weights saved to {save_path}")
# Out:
# Model weights saved to HoViT44_NCT_CRC_HE.pth

# %%
save_path = "HoViT44_NCT_CRC_HE.pth"
model.load_state_dict(torch.load(save_path))
# Out:
# <ipython-input-47-393eca7ae88c>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(save_path))
# <All keys matched successfully>

# %%
from sklearn.metrics import f1_score, recall_score, precision_score
import matplotlib.pyplot as plt

def score_evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_preds = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    overall_f1 = f1_score(all_labels, all_preds, average="macro")
    overall_recall = recall_score(all_labels, all_preds, average="macro")
    overall_precision = precision_score(all_labels, all_preds, average="macro")

    f1_per_class = f1_score(all_labels, all_preds, average=None)
    recall_per_class = recall_score(all_labels, all_preds, average=None)
    precision_per_class = precision_score(all_labels, all_preds, average=None)
    class_labels = sorted(set(all_labels))

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

    print(f"Overall - F1: {overall_f1:.4f}, Recall: {overall_recall:.4f}, Precision: {overall_precision:.4f}")
    print("Per-Class Metrics:")
    for i, label in enumerate(class_labels):
        print(f"Class {label} - F1: {f1_per_class[i]:.4f}, Recall: {recall_per_class[i]:.4f}, Precision: {precision_per_class[i]:.4f}")

    return overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class

# %%
overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class = score_evaluate(model, test_loader, criterion, device)
# Out:
# Validation: 100%|██████████| 469/469 [00:28<00:00, 16.50it/s]
# Validation Loss: 0.0501, Validation Accuracy: 98.51%
# Overall - F1: 0.9848, Recall: 0.9842, Precision: 0.9856
# Per-Class Metrics:
# Class 0 - F1: 0.9961, Recall: 0.9941, Precision: 0.9980
# Class 1 - F1: 0.9960, Recall: 0.9932, Precision: 0.9988
# Class 2 - F1: 0.9813, Recall: 0.9711, Precision: 0.9917
# Class 3 - F1: 0.9973, Recall: 0.9982, Precision: 0.9964
# Class 4 - F1: 0.9763, Recall: 0.9932, Precision: 0.9600
# Class 5 - F1: 0.9827, Recall: 0.9971, Precision: 0.9686
# Class 6 - F1: 0.9793, Recall: 0.9665, Precision: 0.9924
# Class 7 - F1: 0.9670, Recall: 0.9510, Precision: 0.9835
# Class 8 - F1: 0.9875, Recall: 0.9938, Precision: 0.9813

# %%
x = ["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", 'STR', "TUM"]
y = ["F1", "Precision", "Recall"]

f1_score_list = []
precision_score_list = []
recall_score_list = []

for i, class_name in enumerate(x):
    f1_score_list.append(f1_per_class[i])
    precision_score_list.append(precision_per_class[i])
    recall_score_list.append(recall_per_class[i])

x.append("Overall")
f1_score_list.append(overall_f1)
precision_score_list.append(overall_precision)
recall_score_list.append(overall_recall)

score_list = [f1_score_list, precision_score_list, recall_score_list]
score_list = np.array(score_list)
plt.figure(figsize=(20, 12))
score_cm = plt.matshow(score_list, cmap=plt.cm.Blues, alpha=0.3)
plt.xticks(range(len(x)), x)
plt.yticks(range(len(y)), y)
for i in range(len(y)):
    for j in range(len(x)):
        # 행렬의 각각의 수치를 각 칸의 중앙에 넣어준다
        plt.text(x=j, y=i,
                     s="{:.2f}".format(score_list[i, j]),
                     va='center',
                     ha='center',
                     )
