# %%
# !pip install wget torchinfo
# !wget -O NCT-CRC-HE-100K.zip https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# !unzip -qq NCT-CRC-HE-100K.zip -d train
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.11/dist-packages (3.2)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.11/dist-packages (1.8.0)
# --2025-01-24 11:16:21--  https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/1214456/files/NCT-CRC-HE-100K.zip [following]
# --2025-01-24 11:16:22--  https://zenodo.org/records/1214456/files/NCT-CRC-HE-100K.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11690284003 (11G) [application/octet-stream]
# Saving to: ‘NCT-CRC-HE-100K.zip’
#
# NCT-CRC-HE-100K.zip 100%[===================>]  10.89G  18.1MB/s    in 10m 37s
#
# 2025-01-24 11:27:00 (17.5 MB/s) - ‘NCT-CRC-HE-100K.zip’ saved [11690284003/11690284003]
#
# replace train/NCT-CRC-HE-100K/ADI/ADI-AAAMHQMK.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# !pip install torchinfo

import cv2
import timm
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, ConcatDataset
import numpy as np
from tqdm import tqdm

import itertools
from torch import profiler
from torchinfo import summary

from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report, confusion_matrix
from PIL import Image

from matplotlib import pyplot as plt

import random
import torchvision.transforms.functional as TF

from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.11/dist-packages (1.8.0)

# %%
class ConvNorm(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=2, padding=1):
        super(ConvNorm, self).__init__()
        self.linear = nn.Conv2d(
            in_channels, out_channels, kernel_size=kernel_size,
            stride=stride, padding=padding, bias=False
        )
        self.bn = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.linear(x)
        x = self.bn(x)
        return x

# %%
class Stem16(nn.Module):
    def __init__(self):
        super(Stem16, self).__init__()
        self.conv1 = ConvNorm(3, 32)
        self.act1 = nn.Hardswish()
        self.conv2 = ConvNorm(32, 64)
        self.act2 = nn.Hardswish()
        self.conv3 = ConvNorm(64, 128)
        self.act3 = nn.Hardswish()
        self.conv4 = ConvNorm(128, 256)

    def forward(self, x):
        x = self.act1(self.conv1(x))
        x = self.act2(self.conv2(x))
        x = self.act3(self.conv3(x))
        x = self.conv4(x)
        return x

# %%
class LinearNorm(nn.Module):
    def __init__(self, in_features, out_features):
        super(LinearNorm, self).__init__()
        self.linear = nn.Linear(in_features, out_features, bias=False)
        self.bn = nn.BatchNorm1d(out_features)

    def forward(self, x):

        if x.dim() == 3:
            B, N, C = x.shape
            x = x.reshape(B * N, C)
            x = self.bn(self.linear(x))
            x = x.reshape(B, N, -1)
        else:
            x = self.bn(self.linear(x))
        return x

# %%
class Attention(nn.Module):
    def __init__(self, dim, num_heads, attn_ratio=2):
        super(Attention, self).__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5
        inner_dim = head_dim * num_heads * 3
        self.qkv = LinearNorm(dim, inner_dim)

        self.proj = nn.Sequential(
            nn.Hardswish(),
            LinearNorm(dim, dim)
        )

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.view(B, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        return self.proj(x)

# %%
class LevitMlp(nn.Module):
    def __init__(self, in_features, hidden_features, out_features):
        super(LevitMlp, self).__init__()
        self.ln1 = LinearNorm(in_features, hidden_features)
        self.act = nn.Hardswish()
        self.drop = nn.Dropout(p=0.5, inplace=False)
        self.ln2 = LinearNorm(hidden_features, out_features)

    def forward(self, x):
        x = self.ln1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.ln2(x)
        return x

# %%
class LevitBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2):
        super(LevitBlock, self).__init__()
        self.attn = Attention(dim, num_heads)
        self.drop_path1 = nn.Identity()
        self.mlp = LevitMlp(dim, dim * mlp_ratio, dim)
        self.drop_path2 = nn.Identity()

    def forward(self, x):
        x = x + self.drop_path1(self.attn(x))
        x = x + self.drop_path2(self.mlp(x))
        return x

# %%
class CNNDownsample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(CNNDownsample, self).__init__()
        self.out_channels = out_channels
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)
        self.act = nn.Hardswish()

    def forward(self, x):
        # print(x.shape)
        B, N, C = x.shape # (B, N, C)  N=H*W (16 * 16 = 196)
        H = int(np.sqrt(N))
        x = x.view(B, H, H, C).permute(0, 3, 1, 2)
        x = self.conv(x)
        x = self.act(x)
        x = x.permute(0, 2, 3, 1).view(B, -1, self.out_channels)
        return x

# %%
class LevitStage(nn.Module):
    def __init__(self, dim, out_dim, num_heads, num_blocks, downsample=True):
        super(LevitStage, self).__init__()
        self.downsample = CNNDownsample(dim, out_dim) if downsample else nn.Identity()
        self.blocks = nn.Sequential(*[LevitBlock(out_dim, num_heads) for _ in range(num_blocks)])

    def forward(self, x):
        x = self.downsample(x)
        x = self.blocks(x)
        return x

# %%
class ConvLevitStage(nn.Module):
    def __init__(self, in_channels, out_channels, num_blocks, kernel_size, stride, padding):
        super(ConvLevitStage, self).__init__()
        self.layers = nn.Sequential(
            *[nn.Conv2d(in_channels if i == 0 else out_channels, out_channels, kernel_size, stride, padding)
              for i in range(num_blocks)],
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.layers(x)

# %%
class NormLinear(nn.Module):
    def __init__(self, in_features, out_features, dropout_prob=0.5):
        super(NormLinear, self).__init__()
        self.bn = nn.BatchNorm1d(in_features)
        self.drop = nn.Dropout(p=dropout_prob, inplace=False)
        self.linear = nn.Linear(in_features, out_features, bias=True)

    def forward(self, x):
        x = self.bn(x)
        x = self.drop(x)
        x = self.linear(x)
        return x

# %%
class LevitDistilled(nn.Module):
    def __init__(self, num_classes=9):
        super(LevitDistilled, self).__init__()

        self.stem = Stem16()

        self.stage1 = LevitStage(dim=256, out_dim=256, num_heads=4, num_blocks=2, downsample=False)
        self.stage2 = LevitStage(dim=256, out_dim=384, num_heads=6, num_blocks=2, downsample=True)

        self.conv1x1 = nn.Sequential(
            nn.Conv2d(384, 512, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        self.head = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)
        self.head_dist = NormLinear(in_features=512, out_features=num_classes, dropout_prob=0.0)

    def forward(self, x):
        x = self.stem(x)

        B, C, H, W = x.shape
        x = x.view(B, C, -1).transpose(1, 2)
        x = self.stage1(x)
        x = self.stage2(x)

        H = W = int(x.shape[1]**0.5)
        x = x.transpose(1, 2).view(B, 384, H, W)

        x = self.conv1x1(x)

        x = torch.mean(x, dim=(2, 3))
        out = self.head(x)
        out_dist = self.head_dist(x)
        return out

# %%
model = LevitDistilled()
print(model)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# LevitDistilled(
#   (stem): Stem16(
#     (conv1): ConvNorm(
#       (linear): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act1): Hardswish()
#     (conv2): ConvNorm(
#       (linear): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act2): Hardswish()
#     (conv3): ConvNorm(
#       (linear): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act3): Hardswish()
#     (conv4): ConvNorm(
#       (linear): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stage1): LevitStage(
#     (downsample): Identity()
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (stage2): LevitStage(
#     (downsample): CNNDownsample(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): Hardswish()
#     )
#     (blocks): Sequential(
#       (0): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#       (1): LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#   )
#   (conv1x1): Sequential(
#     (0): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (head): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (head_dist): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
batch_size = 16
learning_rate = 5e-4
decay_rate = 1e-6
num_epochs = 30

# %%
print(summary(model, input_size=(32, 3, 224, 224)))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilled                                          [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# ├─LevitStage: 1-2                                       [32, 196, 256]            --
# │    └─Identity: 2-8                                    [32, 196, 256]            --
# │    └─Sequential: 2-9                                  [32, 196, 256]            --
# │    │    └─LevitBlock: 3-9                             [32, 196, 256]            527,872
# │    │    └─LevitBlock: 3-10                            [32, 196, 256]            527,872
# ├─LevitStage: 1-3                                       [32, 49, 384]             --
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─Conv2d: 3-11                                [32, 384, 7, 7]           885,120
# │    │    └─Hardswish: 3-12                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 [32, 49, 384]             --
# │    │    └─LevitBlock: 3-13                            [32, 49, 384]             1,185,024
# │    │    └─LevitBlock: 3-14                            [32, 49, 384]             1,185,024
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# =========================================================================================================
# Total params: 4,909,234
# Trainable params: 4,909,234
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 17.93
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 897.82
# Params size (MB): 19.64
# Estimated Total Size (MB): 936.72
# =========================================================================================================

# %%
print(summary(model, input_size=(32, 3, 224, 224), verbose=2))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilled                                          [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                                        ├─864
# │    └─conv1.bn.weight                                                            ├─32
# │    └─conv1.bn.bias                                                              ├─32
# │    └─conv2.linear.weight                                                        ├─18,432
# │    └─conv2.bn.weight                                                            ├─64
# │    └─conv2.bn.bias                                                              ├─64
# │    └─conv3.linear.weight                                                        ├─73,728
# │    └─conv3.bn.weight                                                            ├─128
# │    └─conv3.bn.bias                                                              ├─128
# │    └─conv4.linear.weight                                                        ├─294,912
# │    └─conv4.bn.weight                                                            ├─256
# │    └─conv4.bn.bias                                                              └─256
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─linear.weight                                                         ├─864
# │    │    └─bn.weight                                                             ├─32
# │    │    └─bn.bias                                                               └─32
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    │    └─weight                                                           └─864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    │    │    └─weight                                                           ├─32
# │    │    │    └─bias                                                             └─32
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─linear.weight                                                         ├─18,432
# │    │    └─bn.weight                                                             ├─64
# │    │    └─bn.bias                                                               └─64
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                                           └─18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    │    │    └─weight                                                           ├─64
# │    │    │    └─bias                                                             └─64
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─linear.weight                                                         ├─73,728
# │    │    └─bn.weight                                                             ├─128
# │    │    └─bn.bias                                                               └─128
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                                           └─73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    │    │    └─weight                                                           ├─128
# │    │    │    └─bias                                                             └─128
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─linear.weight                                                         ├─294,912
# │    │    └─bn.weight                                                             ├─256
# │    │    └─bn.bias                                                               └─256
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                                           └─294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# │    │    │    └─weight                                                           ├─256
# │    │    │    └─bias                                                             └─256
# ├─LevitStage: 1-2                                       [32, 196, 256]            --
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                                   └─256
# │    └─Identity: 2-8                                    [32, 196, 256]            --
# │    └─Sequential: 2-9                                  [32, 196, 256]            --
# │    │    └─0.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─0.attn.qkv.bn.weight                                                  ├─768
# │    │    └─0.attn.qkv.bn.bias                                                    ├─768
# │    │    └─0.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─0.attn.proj.1.bn.weight                                               ├─256
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─0.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─0.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─1.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─1.attn.qkv.bn.weight                                                  ├─768
# │    │    └─1.attn.qkv.bn.bias                                                    ├─768
# │    │    └─1.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─1.attn.proj.1.bn.weight                                               ├─256
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─1.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─1.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─1.mlp.ln2.bn.bias                                                     └─256
# │    │    └─LevitBlock: 3-9                             [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# │    │    └─LevitBlock: 3-10                            [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# ├─LevitStage: 1-3                                       [32, 49, 384]             --
# │    └─downsample.conv.weight                                                     ├─884,736
# │    └─downsample.conv.bias                                                       ├─384
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                                   └─384
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─conv.weight                                                           ├─884,736
# │    │    └─conv.bias                                                             └─384
# │    │    └─Conv2d: 3-11                                [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                                           ├─884,736
# │    │    │    └─bias                                                             └─384
# │    │    └─Hardswish: 3-12                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 [32, 49, 384]             --
# │    │    └─0.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─0.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─0.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─0.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─0.attn.proj.1.bn.weight                                               ├─384
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─0.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─0.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─1.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─1.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─1.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─1.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─1.attn.proj.1.bn.weight                                               ├─384
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─1.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─1.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─1.mlp.ln2.bn.bias                                                     └─384
# │    │    └─LevitBlock: 3-13                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-14                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─0.weight                                                                   ├─196,608
# │    └─0.bias                                                                     ├─512
# │    └─1.weight                                                                   ├─512
# │    └─1.bias                                                                     └─512
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    │    └─weight                                                                ├─196,608
# │    │    └─bias                                                                  └─512
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# =========================================================================================================
# Total params: 4,909,234
# Trainable params: 4,909,234
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 17.93
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 897.82
# Params size (MB): 19.64
# Estimated Total Size (MB): 936.72
# =========================================================================================================
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LevitDistilled                                          [32, 9]                   --
# ├─Stem16: 1-1                                           [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                                        ├─864
# │    └─conv1.bn.weight                                                            ├─32
# │    └─conv1.bn.bias                                                              ├─32
# │    └─conv2.linear.weight                                                        ├─18,432
# │    └─conv2.bn.weight                                                            ├─64
# │    └─conv2.bn.bias                                                              ├─64
# │    └─conv3.linear.weight                                                        ├─73,728
# │    └─conv3.bn.weight                                                            ├─128
# │    └─conv3.bn.bias                                                              ├─128
# │    └─conv4.linear.weight                                                        ├─294,912
# │    └─conv4.bn.weight                                                            ├─256
# │    └─conv4.bn.bias                                                              └─256
# │    └─ConvNorm: 2-1                                    [32, 32, 112, 112]        --
# │    │    └─linear.weight                                                         ├─864
# │    │    └─bn.weight                                                             ├─32
# │    │    └─bn.bias                                                               └─32
# │    │    └─Conv2d: 3-1                                 [32, 32, 112, 112]        864
# │    │    │    └─weight                                                           └─864
# │    │    └─BatchNorm2d: 3-2                            [32, 32, 112, 112]        64
# │    │    │    └─weight                                                           ├─32
# │    │    │    └─bias                                                             └─32
# │    └─Hardswish: 2-2                                   [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                                    [32, 64, 56, 56]          --
# │    │    └─linear.weight                                                         ├─18,432
# │    │    └─bn.weight                                                             ├─64
# │    │    └─bn.bias                                                               └─64
# │    │    └─Conv2d: 3-3                                 [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                                           └─18,432
# │    │    └─BatchNorm2d: 3-4                            [32, 64, 56, 56]          128
# │    │    │    └─weight                                                           ├─64
# │    │    │    └─bias                                                             └─64
# │    └─Hardswish: 2-4                                   [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                                    [32, 128, 28, 28]         --
# │    │    └─linear.weight                                                         ├─73,728
# │    │    └─bn.weight                                                             ├─128
# │    │    └─bn.bias                                                               └─128
# │    │    └─Conv2d: 3-5                                 [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                                           └─73,728
# │    │    └─BatchNorm2d: 3-6                            [32, 128, 28, 28]         256
# │    │    │    └─weight                                                           ├─128
# │    │    │    └─bias                                                             └─128
# │    └─Hardswish: 2-6                                   [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                                    [32, 256, 14, 14]         --
# │    │    └─linear.weight                                                         ├─294,912
# │    │    └─bn.weight                                                             ├─256
# │    │    └─bn.bias                                                               └─256
# │    │    └─Conv2d: 3-7                                 [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                                           └─294,912
# │    │    └─BatchNorm2d: 3-8                            [32, 256, 14, 14]         512
# │    │    │    └─weight                                                           ├─256
# │    │    │    └─bias                                                             └─256
# ├─LevitStage: 1-2                                       [32, 196, 256]            --
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─256
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                                   └─256
# │    └─Identity: 2-8                                    [32, 196, 256]            --
# │    └─Sequential: 2-9                                  [32, 196, 256]            --
# │    │    └─0.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─0.attn.qkv.bn.weight                                                  ├─768
# │    │    └─0.attn.qkv.bn.bias                                                    ├─768
# │    │    └─0.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─0.attn.proj.1.bn.weight                                               ├─256
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─0.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─0.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─256
# │    │    └─1.attn.qkv.linear.weight                                              ├─196,608
# │    │    └─1.attn.qkv.bn.weight                                                  ├─768
# │    │    └─1.attn.qkv.bn.bias                                                    ├─768
# │    │    └─1.attn.proj.1.linear.weight                                           ├─65,536
# │    │    └─1.attn.proj.1.bn.weight                                               ├─256
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─256
# │    │    └─1.mlp.ln1.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─512
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─512
# │    │    └─1.mlp.ln2.linear.weight                                               ├─131,072
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─256
# │    │    └─1.mlp.ln2.bn.bias                                                     └─256
# │    │    └─LevitBlock: 3-9                             [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# │    │    └─LevitBlock: 3-10                            [32, 196, 256]            527,872
# │    │    │    └─attn.qkv.linear.weight                                           ├─196,608
# │    │    │    └─attn.qkv.bn.weight                                               ├─768
# │    │    │    └─attn.qkv.bn.bias                                                 ├─768
# │    │    │    └─attn.proj.1.linear.weight                                        ├─65,536
# │    │    │    └─attn.proj.1.bn.weight                                            ├─256
# │    │    │    └─attn.proj.1.bn.bias                                              ├─256
# │    │    │    └─mlp.ln1.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln1.bn.weight                                                ├─512
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─512
# │    │    │    └─mlp.ln2.linear.weight                                            ├─131,072
# │    │    │    └─mlp.ln2.bn.weight                                                ├─256
# │    │    │    └─mlp.ln2.bn.bias                                                  └─256
# ├─LevitStage: 1-3                                       [32, 49, 384]             --
# │    └─downsample.conv.weight                                                     ├─884,736
# │    └─downsample.conv.bias                                                       ├─384
# │    └─blocks.0.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                                   ├─384
# │    └─blocks.1.attn.qkv.linear.weight                                            ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                                ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                                  ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                                         ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                                             ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                               ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                                 ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                                   ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                                             ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                                 ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                                   └─384
# │    └─CNNDownsample: 2-10                              [32, 49, 384]             --
# │    │    └─conv.weight                                                           ├─884,736
# │    │    └─conv.bias                                                             └─384
# │    │    └─Conv2d: 3-11                                [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                                           ├─884,736
# │    │    │    └─bias                                                             └─384
# │    │    └─Hardswish: 3-12                             [32, 384, 7, 7]           --
# │    └─Sequential: 2-11                                 [32, 49, 384]             --
# │    │    └─0.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─0.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─0.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─0.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─0.attn.proj.1.bn.weight                                               ├─384
# │    │    └─0.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─0.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─0.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─0.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─0.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─0.mlp.ln2.bn.bias                                                     ├─384
# │    │    └─1.attn.qkv.linear.weight                                              ├─442,368
# │    │    └─1.attn.qkv.bn.weight                                                  ├─1,152
# │    │    └─1.attn.qkv.bn.bias                                                    ├─1,152
# │    │    └─1.attn.proj.1.linear.weight                                           ├─147,456
# │    │    └─1.attn.proj.1.bn.weight                                               ├─384
# │    │    └─1.attn.proj.1.bn.bias                                                 ├─384
# │    │    └─1.mlp.ln1.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln1.bn.weight                                                   ├─768
# │    │    └─1.mlp.ln1.bn.bias                                                     ├─768
# │    │    └─1.mlp.ln2.linear.weight                                               ├─294,912
# │    │    └─1.mlp.ln2.bn.weight                                                   ├─384
# │    │    └─1.mlp.ln2.bn.bias                                                     └─384
# │    │    └─LevitBlock: 3-13                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# │    │    └─LevitBlock: 3-14                            [32, 49, 384]             1,185,024
# │    │    │    └─attn.qkv.linear.weight                                           ├─442,368
# │    │    │    └─attn.qkv.bn.weight                                               ├─1,152
# │    │    │    └─attn.qkv.bn.bias                                                 ├─1,152
# │    │    │    └─attn.proj.1.linear.weight                                        ├─147,456
# │    │    │    └─attn.proj.1.bn.weight                                            ├─384
# │    │    │    └─attn.proj.1.bn.bias                                              ├─384
# │    │    │    └─mlp.ln1.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln1.bn.weight                                                ├─768
# │    │    │    └─mlp.ln1.bn.bias                                                  ├─768
# │    │    │    └─mlp.ln2.linear.weight                                            ├─294,912
# │    │    │    └─mlp.ln2.bn.weight                                                ├─384
# │    │    │    └─mlp.ln2.bn.bias                                                  └─384
# ├─Sequential: 1-4                                       [32, 512, 7, 7]           --
# │    └─0.weight                                                                   ├─196,608
# │    └─0.bias                                                                     ├─512
# │    └─1.weight                                                                   ├─512
# │    └─1.bias                                                                     └─512
# │    └─Conv2d: 2-12                                     [32, 512, 7, 7]           197,120
# │    │    └─weight                                                                ├─196,608
# │    │    └─bias                                                                  └─512
# │    └─BatchNorm2d: 2-13                                [32, 512, 7, 7]           1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─ReLU: 2-14                                       [32, 512, 7, 7]           --
# ├─NormLinear: 1-5                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-15                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-16                                    [32, 512]                 --
# │    └─Linear: 2-17                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# ├─NormLinear: 1-6                                       [32, 9]                   --
# │    └─bn.weight                                                                  ├─512
# │    └─bn.bias                                                                    ├─512
# │    └─linear.weight                                                              ├─4,608
# │    └─linear.bias                                                                └─9
# │    └─BatchNorm1d: 2-18                                [32, 512]                 1,024
# │    │    └─weight                                                                ├─512
# │    │    └─bias                                                                  └─512
# │    └─Dropout: 2-19                                    [32, 512]                 --
# │    └─Linear: 2-20                                     [32, 9]                   4,617
# │    │    └─weight                                                                ├─4,608
# │    │    └─bias                                                                  └─9
# =========================================================================================================
# Total params: 4,909,234
# Trainable params: 4,909,234
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 17.93
# =========================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 897.82
# Params size (MB): 19.64
# Estimated Total Size (MB): 936.72
# =========================================================================================================

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
train_dir = './train/NCT-CRC-HE-100K'
dataset = datasets.ImageFolder(root=train_dir, transform=transform)

# %%
data_paths, labels = zip(*dataset.samples)
labels = np.array(labels)

# 7 : 3 split
train_idx, tmp_idx, _, tmp_labels = train_test_split(
    np.arange(len(labels)), labels, test_size=0.3, stratify=labels, random_state=42
)

# 3 -> 1.5 : 1.5 split
val_idx, test_idx = train_test_split(
    tmp_idx, test_size=0.5, stratify=tmp_labels, random_state=42
)

train_data = Subset(dataset, train_idx)
val_data = Subset(dataset, val_idx)
test_data = Subset(dataset, test_idx)

# %%
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Train set size: 70000
# Validation set size: 15000
# Test set size: 15000

# %%
# Show one example per class from the training dataset
import matplotlib.pyplot as plt

# Prepare a dictionary to store one example per class
class_examples = {}
for images, labels in train_loader:
    for img, label in zip(images, labels):
        label = label.item()
        if label not in class_examples:
            class_examples[label] = img
        # Stop if we already have one example for each class
        if len(class_examples) == len(dataset.classes):
            break
    if len(class_examples) == len(dataset.classes):
        break

# Display the images and their labels
figure = plt.figure(figsize=(8, 8))
cols = 3  # You can adjust the number of columns as needed
rows = (len(dataset.classes) + cols - 1) // cols  # Calculate required rows
for i, (label, img) in enumerate(class_examples.items(), start=1):
    figure.add_subplot(rows, cols, i)
    plt.title(dataset.classes[label])
    plt.axis("off")
    plt.imshow(img.permute(1, 2, 0).numpy())  # Convert tensor to numpy for display
plt.show()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay = decay_rate)

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in tqdm(train_loader, desc="Training"):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {accuracy:.2f}%")
    train_losses.append(epoch_loss)
    train_accuracies.append(accuracy)

# %%
def evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

# %%
def measure_inference_time(model, data_loader, device):
    model.eval()
    times = []

    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            start_time = torch.cuda.Event(enable_timing=True)
            end_time = torch.cuda.Event(enable_timing=True)

            start_time.record()
            _ = model(inputs)  # inference 수행
            end_time.record()

            # 시간 측정
            torch.cuda.synchronize()  # CUDA에서 모든 커널이 완료될 때까지 대기
            elapsed_time = start_time.elapsed_time(end_time)  # 밀리초 단위로 반환
            times.append(elapsed_time)

    # 통계량 계산
    times_np = np.array(times)
    total_inferences = len(times_np)
    avg_time = np.mean(times_np)
    std_dev = np.std(times_np)
    max_time = np.max(times_np)
    min_time = np.min(times_np)

    # 결과 출력
    print(f"Inference Time Measurement Results:")
    print(f"Total Inferences: {total_inferences}")
    print(f"Average Time: {avg_time:.2f} ms")
    print(f"Standard Deviation: {std_dev:.2f} ms")
    print(f"Maximum Time: {max_time:.2f} ms")
    print(f"Minimum Time: {min_time:.2f} ms")

    return times

# %%
for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    train(model, train_loader, criterion, optimizer, device)
    evaluate(model, val_loader, criterion, device, phase="Validation")
# Out:
# Epoch 1/30
# Training: 100%|██████████| 4375/4375 [02:35<00:00, 28.21it/s]
# Train Loss: 0.5525, Train Accuracy: 80.66%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.54it/s]
# Validation Loss: 0.4107, Validation Accuracy: 85.79%
#
# Epoch 2/30
# Training: 100%|██████████| 4375/4375 [02:33<00:00, 28.54it/s]
# Train Loss: 0.2660, Train Accuracy: 90.88%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.48it/s]
# Validation Loss: 0.3292, Validation Accuracy: 89.05%
#
# Epoch 3/30
# Training: 100%|██████████| 4375/4375 [02:33<00:00, 28.59it/s]
# Train Loss: 0.1909, Train Accuracy: 93.54%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.58it/s]
# Validation Loss: 0.2707, Validation Accuracy: 90.56%
#
# Epoch 4/30
# Training: 100%|██████████| 4375/4375 [02:33<00:00, 28.51it/s]
# Train Loss: 0.1459, Train Accuracy: 95.14%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.57it/s]
# Validation Loss: 0.2765, Validation Accuracy: 89.73%
#
# Epoch 5/30
# Training: 100%|██████████| 4375/4375 [02:33<00:00, 28.57it/s]
# Train Loss: 0.1154, Train Accuracy: 96.18%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.56it/s]
# Validation Loss: 0.1701, Validation Accuracy: 94.22%
#
# Epoch 6/30
# Training: 100%|██████████| 4375/4375 [02:33<00:00, 28.56it/s]
# Train Loss: 0.1001, Train Accuracy: 96.63%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.62it/s]
# Validation Loss: 0.2452, Validation Accuracy: 92.31%
#
# Epoch 7/30
# Training: 100%|██████████| 4375/4375 [02:35<00:00, 28.12it/s]
# Train Loss: 0.0859, Train Accuracy: 97.12%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.22it/s]
# Validation Loss: 0.2107, Validation Accuracy: 93.69%
#
# Epoch 8/30
# Training: 100%|██████████| 4375/4375 [02:38<00:00, 27.68it/s]
# Train Loss: 0.0744, Train Accuracy: 97.44%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.43it/s]
# Validation Loss: 0.0808, Validation Accuracy: 97.35%
#
# Epoch 9/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.78it/s]
# Train Loss: 0.0652, Train Accuracy: 97.81%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.63it/s]
# Validation Loss: 0.0893, Validation Accuracy: 97.03%
#
# Epoch 10/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.85it/s]
# Train Loss: 0.0623, Train Accuracy: 97.98%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.35it/s]
# Validation Loss: 0.0600, Validation Accuracy: 98.04%
#
# Epoch 11/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.82it/s]
# Train Loss: 0.0522, Train Accuracy: 98.28%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.47it/s]
# Validation Loss: 0.0584, Validation Accuracy: 98.27%
#
# Epoch 12/30
# Training: 100%|██████████| 4375/4375 [02:36<00:00, 27.94it/s]
# Train Loss: 0.0484, Train Accuracy: 98.35%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.00it/s]
# Validation Loss: 0.0649, Validation Accuracy: 97.87%
#
# Epoch 13/30
# Training: 100%|██████████| 4375/4375 [02:33<00:00, 28.49it/s]
# Train Loss: 0.0442, Train Accuracy: 98.50%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.61it/s]
# Validation Loss: 0.0703, Validation Accuracy: 97.72%
#
# Epoch 14/30
# Training: 100%|██████████| 4375/4375 [02:36<00:00, 27.97it/s]
# Train Loss: 0.0419, Train Accuracy: 98.61%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.30it/s]
# Validation Loss: 0.0790, Validation Accuracy: 97.35%
#
# Epoch 15/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.86it/s]
# Train Loss: 0.0356, Train Accuracy: 98.81%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.30it/s]
# Validation Loss: 0.1600, Validation Accuracy: 95.11%
#
# Epoch 16/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.86it/s]
# Train Loss: 0.0351, Train Accuracy: 98.83%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.47it/s]
# Validation Loss: 0.0857, Validation Accuracy: 97.09%
#
# Epoch 17/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.80it/s]
# Train Loss: 0.0336, Train Accuracy: 98.90%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.43it/s]
# Validation Loss: 0.0725, Validation Accuracy: 97.67%
#
# Epoch 18/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.73it/s]
# Train Loss: 0.0315, Train Accuracy: 98.99%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.57it/s]
# Validation Loss: 0.0623, Validation Accuracy: 98.14%
#
# Epoch 19/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.74it/s]
# Train Loss: 0.0303, Train Accuracy: 98.99%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.24it/s]
# Validation Loss: 0.0520, Validation Accuracy: 98.37%
#
# Epoch 20/30
# Training: 100%|██████████| 4375/4375 [02:38<00:00, 27.66it/s]
# Train Loss: 0.0281, Train Accuracy: 99.09%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.51it/s]
# Validation Loss: 0.0508, Validation Accuracy: 98.28%
#
# Epoch 21/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.76it/s]
# Train Loss: 0.0274, Train Accuracy: 99.10%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.38it/s]
# Validation Loss: 0.0591, Validation Accuracy: 98.15%
#
# Epoch 22/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.81it/s]
# Train Loss: 0.0259, Train Accuracy: 99.12%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.29it/s]
# Validation Loss: 0.0422, Validation Accuracy: 98.67%
#
# Epoch 23/30
# Training: 100%|██████████| 4375/4375 [02:34<00:00, 28.23it/s]
# Train Loss: 0.0245, Train Accuracy: 99.18%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.69it/s]
# Validation Loss: 0.0521, Validation Accuracy: 98.41%
#
# Epoch 24/30
# Training: 100%|██████████| 4375/4375 [02:34<00:00, 28.26it/s]
# Train Loss: 0.0217, Train Accuracy: 99.23%
# Validation: 100%|██████████| 938/938 [00:22<00:00, 41.31it/s]
# Validation Loss: 0.0551, Validation Accuracy: 98.76%
#
# Epoch 25/30
# Training: 100%|██████████| 4375/4375 [02:34<00:00, 28.34it/s]
# Train Loss: 0.0228, Train Accuracy: 99.23%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.37it/s]
# Validation Loss: 0.1268, Validation Accuracy: 96.50%
#
# Epoch 26/30
# Training: 100%|██████████| 4375/4375 [02:37<00:00, 27.75it/s]
# Train Loss: 0.0207, Train Accuracy: 99.32%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.28it/s]
# Validation Loss: 0.0563, Validation Accuracy: 98.15%
#
# Epoch 27/30
# Training: 100%|██████████| 4375/4375 [02:38<00:00, 27.66it/s]
# Train Loss: 0.0214, Train Accuracy: 99.32%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.38it/s]
# Validation Loss: 0.0389, Validation Accuracy: 98.79%
#
# Epoch 28/30
# Training: 100%|██████████| 4375/4375 [02:38<00:00, 27.59it/s]
# Train Loss: 0.0194, Train Accuracy: 99.39%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.31it/s]
# Validation Loss: 0.0896, Validation Accuracy: 97.39%
#
# Epoch 29/30
# Training: 100%|██████████| 4375/4375 [02:38<00:00, 27.55it/s]
# Train Loss: 0.0196, Train Accuracy: 99.33%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.35it/s]
# Validation Loss: 0.0691, Validation Accuracy: 98.05%
#
# Epoch 30/30
# Training: 100%|██████████| 4375/4375 [02:38<00:00, 27.66it/s]
# Train Loss: 0.0181, Train Accuracy: 99.44%
# Validation: 100%|██████████| 938/938 [00:23<00:00, 40.47it/s]
# Validation Loss: 0.0456, Validation Accuracy: 98.66%

# %%
print("\nFinal Test Evaluation")
evaluate(model, test_loader, criterion, device, phase="Test")
# Out:
# Final Test Evaluation
# Test: 100%|██████████| 938/938 [00:23<00:00, 39.45it/s]
# Test Loss: 0.0385, Test Accuracy: 98.89%

# %%
print("train_loss length : ", len(train_losses))
print("train_acc length : ", len(train_accuracies))
print("val_loss length : ", len(val_losses))
print("val_acc length : ", len(val_accuracies))

print("val_adj : ", len(val_losses[:num_epochs]))
print("val_acc_adj : ", len(val_accuracies[:num_epochs]))
# Out:
# train_loss length :  30
# train_acc length :  30
# val_loss length :  31
# val_acc length :  31
# val_adj :  30
# val_acc_adj :  30

# %%
# Plot the metrics
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 5))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses[:num_epochs], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label="Train Accuracy")
plt.plot(epochs, val_accuracies[:num_epochs], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
times = measure_inference_time(model, test_loader, device)
# Out:
# Inference Time Measurement Results:
# Total Inferences: 938
# Average Time: 5.55 ms
# Standard Deviation: 0.42 ms
# Maximum Time: 8.70 ms
# Minimum Time: 5.15 ms

# %%
dummy_input = torch.randn(32, 3, 224, 224).cuda()

# Profiling inference
with profiler.profile(
    activities=[
       profiler.ProfilerActivity.CPU,
        profiler.ProfilerActivity.CUDA,  # Include if using GPU
    ],
    on_trace_ready=profiler.tensorboard_trace_handler("./logs"),  # Optional logging
    record_shapes=True,
    with_stack=True
) as prof:
    with torch.no_grad():
        model(dummy_input)


# Print results
print(prof.key_averages().table(sort_by="cuda_time_total" if torch.cuda.is_available() else "cpu_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::matmul         2.54%     298.804us        25.05%       2.952ms     123.010us       0.000us         0.00%       2.561ms     106.720us            24
#                                            aten::linear         0.83%      98.202us        18.46%       2.176ms     120.869us       0.000us         0.00%       1.851ms     102.834us            18
#                                                aten::mm         5.15%     606.684us        14.34%       1.690ms     105.608us       1.828ms        40.52%       1.828ms     114.226us            16
#                                  ampere_sgemm_32x128_tn         0.00%       0.000us         0.00%       0.000us       0.000us     687.360us        15.24%     687.360us     171.840us             4
#                                            aten::conv2d         1.17%     137.590us        19.53%       2.302ms     383.631us       0.000us         0.00%     619.807us     103.301us             6
#                                       aten::convolution         0.43%      50.565us        18.36%       2.164ms     360.700us       0.000us         0.00%     619.807us     103.301us             6
#                                      aten::_convolution         6.30%     742.600us        17.94%       2.114ms     352.272us       0.000us         0.00%     619.807us     103.301us             6
#                                 aten::cudnn_convolution         8.91%       1.050ms        11.16%       1.315ms     219.166us     605.055us        13.42%     605.055us     100.843us             6
#                                               aten::bmm         2.19%     258.259us         2.74%     322.993us      40.374us     571.166us        12.66%     571.166us      71.396us             8
#                                        aten::batch_norm         1.12%     132.291us        34.22%       4.032ms     175.324us       0.000us         0.00%     543.485us      23.630us            23
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 11.784ms
# Self CUDA time total: 4.510ms

# %%
save_path = "HoviT_Batch16_NCT_CRC_HE.pth"
torch.save(model.state_dict(), save_path)
print(f"Model weights saved to {save_path}")
# Out:
# Model weights saved to HoviT_Batch16_NCT_CRC_HE.pth

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, roc_curve, auc

def score_evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_preds = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    overall_f1 = f1_score(all_labels, all_preds, average="macro")
    overall_recall = recall_score(all_labels, all_preds, average="macro")
    overall_precision = precision_score(all_labels, all_preds, average="macro")

    f1_per_class = f1_score(all_labels, all_preds, average=None)
    recall_per_class = recall_score(all_labels, all_preds, average=None)
    precision_per_class = precision_score(all_labels, all_preds, average=None)
    class_labels = sorted(set(all_labels))

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

    print(f"Overall - F1: {overall_f1:.4f}, Recall: {overall_recall:.4f}, Precision: {overall_precision:.4f}")
    print("Per-Class Metrics:")
    for i, label in enumerate(class_labels):
        print(f"Class {label} - F1: {f1_per_class[i]:.4f}, Recall: {recall_per_class[i]:.4f}, Precision: {precision_per_class[i]:.4f}")

    return overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class

# %%
overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class = score_evaluate(model, test_loader, criterion, device, phase="Test")
# Out:
# Test: 100%|██████████| 938/938 [00:25<00:00, 37.36it/s]
# Test Loss: 0.0385, Test Accuracy: 98.89%
# Overall - F1: 0.9889, Recall: 0.9888, Precision: 0.9891
# Per-Class Metrics:
# Class 0 - F1: 0.9965, Recall: 0.9930, Precision: 1.0000
# Class 1 - F1: 0.9984, Recall: 0.9975, Precision: 0.9994
# Class 2 - F1: 0.9831, Recall: 0.9925, Precision: 0.9738
# Class 3 - F1: 0.9977, Recall: 0.9988, Precision: 0.9965
# Class 4 - F1: 0.9899, Recall: 0.9895, Precision: 0.9903
# Class 5 - F1: 0.9849, Recall: 0.9778, Precision: 0.9920
# Class 6 - F1: 0.9870, Recall: 0.9779, Precision: 0.9961
# Class 7 - F1: 0.9737, Recall: 0.9809, Precision: 0.9667
# Class 8 - F1: 0.9893, Recall: 0.9912, Precision: 0.9875

# %%
from sklearn.preprocessing import label_binarize

def roc_auc(model, data_loader, device, num_classes):

    y = ["F1", "Precision", "Recall"]

    model.eval()
    all_labels = []
    all_scores = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc="ROC AUC"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            all_labels.extend(labels.cpu().numpy())
            all_scores.extend(outputs.cpu().numpy())

    all_labels = label_binarize(all_labels, classes=list(range(num_classes)))
    print(f"Binarized all_labels shape: {all_labels.shape}")
    print(f"All_scores shape: {np.array(all_scores).shape}")

    fpr, tpr, _ = roc_curve(all_labels.ravel(), np.array(all_scores).ravel())
    roc_auc_value = auc(fpr, tpr)

    plt.figure(figsize=(9, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc_value:0.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.show()

    print(f"Overall ROC AUC: {roc_auc_value:.4f}")

    return fpr, tpr, roc_auc_value

# %%
fpr, tpr, roc_auc_value = roc_auc(model, test_loader, device, num_classes=9)
# Out:
# ROC AUC: 100%|██████████| 938/938 [00:25<00:00, 37.34it/s]
# Binarized all_labels shape: (15000, 9)
# All_scores shape: (15000, 9)
# Overall ROC AUC: 0.9985

# %%
x = ["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", 'STR', "TUM"]
y = ["F1", "Precision", "Recall"]

f1_score_list = []
precision_score_list = []
recall_score_list = []

for i, class_name in enumerate(x):
    f1_score_list.append(f1_per_class[i])
    precision_score_list.append(precision_per_class[i])
    recall_score_list.append(recall_per_class[i])

x.append("Overall")
f1_score_list.append(overall_f1)
precision_score_list.append(overall_precision)
recall_score_list.append(overall_recall)

score_list = [f1_score_list, precision_score_list, recall_score_list]
score_list = np.array(score_list)
plt.figure(figsize=(20, 12))
score_cm = plt.matshow(score_list, cmap=plt.cm.Blues, alpha=0.3)
plt.xticks(range(len(x)), x)
plt.yticks(range(len(y)), y)
for i in range(len(y)):
    for j in range(len(x)):
        # 행렬의 각각의 수치를 각 칸의 중앙에 넣어준다
        plt.text(x=j, y=i,
                     s="{:.2f}".format(score_list[i, j]),
                     va='center',
                     ha='center',
                     )
