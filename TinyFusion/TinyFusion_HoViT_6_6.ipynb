# %%
# !wget -O NCT-CRC-HE-100K.zip https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# !unzip -qq NCT-CRC-HE-100K.zip -d train
# !pip install torchinfo
# Out:
# --2025-02-09 07:35:09--  https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/1214456/files/NCT-CRC-HE-100K.zip [following]
# --2025-02-09 07:35:09--  https://zenodo.org/records/1214456/files/NCT-CRC-HE-100K.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11690284003 (11G) [application/octet-stream]
# Saving to: ‘NCT-CRC-HE-100K.zip’
#
# NCT-CRC-HE-100K.zip 100%[===================>]  10.89G  12.0MB/s    in 13m 24s
#
# 2025-02-09 07:48:33 (13.9 MB/s) - ‘NCT-CRC-HE-100K.zip’ saved [11690284003/11690284003]
#
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import timm
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, ConcatDataset
import numpy as np
from tqdm import tqdm

import itertools
from torchinfo import summary
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report, confusion_matrix
from PIL import Image

from matplotlib import pyplot as plt

import random
import torchvision.transforms.functional as TF

from sklearn.model_selection import train_test_split
from torch.utils.data import Subset

import torch.nn.functional as F

# %%
class ConvNorm(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=2, padding=1):
        super(ConvNorm, self).__init__()
        self.linear = nn.Conv2d(
            in_channels, out_channels, kernel_size=kernel_size,
            stride=stride, padding=padding, bias=False
        )
        self.bn = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.linear(x)
        x = self.bn(x)
        return x

# %%
class Stem16(nn.Module):
    def __init__(self):
        super(Stem16, self).__init__()
        self.conv1 = ConvNorm(3, 32)
        self.act1 = nn.Hardswish()
        self.conv2 = ConvNorm(32, 64)
        self.act2 = nn.Hardswish()
        self.conv3 = ConvNorm(64, 128)
        self.act3 = nn.Hardswish()
        self.conv4 = ConvNorm(128, 256)

    def forward(self, x):
        x = self.act1(self.conv1(x))
        x = self.act2(self.conv2(x))
        x = self.act3(self.conv3(x))
        x = self.conv4(x)
        return x

# %%
class LinearNorm(nn.Module):
    def __init__(self, in_features, out_features):
        super(LinearNorm, self).__init__()
        self.linear = nn.Linear(in_features, out_features, bias=False)
        self.bn = nn.BatchNorm1d(out_features)

    def forward(self, x):

        if x.dim() == 3:
            B, N, C = x.shape
            x = x.reshape(B * N, C)
            x = self.bn(self.linear(x))
            x = x.reshape(B, N, -1)
        else:
            x = self.bn(self.linear(x))
        return x

# %%
class Attention(nn.Module):
    def __init__(self, dim, num_heads, attn_ratio=2):
        super(Attention, self).__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5
        inner_dim = head_dim * num_heads * 3
        self.qkv = LinearNorm(dim, inner_dim)

        self.proj = nn.Sequential(
            nn.Hardswish(),
            LinearNorm(dim, dim)
        )

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.view(B, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        return self.proj(x)

# %%
class LevitMlp(nn.Module):
    def __init__(self, in_features, hidden_features, out_features):
        super(LevitMlp, self).__init__()
        self.ln1 = LinearNorm(in_features, hidden_features)
        self.act = nn.Hardswish()
        self.drop = nn.Dropout(p=0.5, inplace=False)#dropout 적용
        self.ln2 = LinearNorm(hidden_features, out_features)

    def forward(self, x):
        x = self.ln1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.ln2(x)
        return x

# %%
class LevitBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=2):
        super(LevitBlock, self).__init__()
        self.attn = Attention(dim, num_heads)
        self.drop_path1 = nn.Identity()
        self.mlp = LevitMlp(dim, dim * mlp_ratio, dim)
        self.drop_path2 = nn.Identity()

    def forward(self, x):
        x = x + self.drop_path1(self.attn(x))
        x = x + self.drop_path2(self.mlp(x))
        return x

# %%
class CNNDownsample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(CNNDownsample, self).__init__()
        self.out_channels = out_channels
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)
        self.act = nn.Hardswish()

    def forward(self, x):
        # print(x.shape)
        B, N, C = x.shape # (B, N, C)  N=H*W (16 * 16 = 196)
        H = int(np.sqrt(N))
        x = x.view(B, H, H, C).permute(0, 3, 1, 2)
        x = self.conv(x)
        x = self.act(x)
        x = x.permute(0, 2, 3, 1).view(B, -1, self.out_channels)
        return x

# %%
class ConvLevitStage(nn.Module):
    def __init__(self, in_channels, out_channels, num_blocks, kernel_size, stride, padding):
        super(ConvLevitStage, self).__init__()
        self.layers = nn.Sequential(
            *[nn.Conv2d(in_channels if i == 0 else out_channels, out_channels, kernel_size, stride, padding)
              for i in range(num_blocks)],
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.layers(x)

# %%
class NormLinear(nn.Module):
    def __init__(self, in_features, out_features, dropout_prob=0.5):#drop_out_0.5 적용
        super(NormLinear, self).__init__()
        self.bn = nn.BatchNorm1d(in_features)
        self.drop = nn.Dropout(p=dropout_prob, inplace=False)
        self.linear = nn.Linear(in_features, out_features, bias=True)

    def forward(self, x):
        x = self.bn(x)
        x = self.drop(x)
        x = self.linear(x)
        return x

# %%
class SimpleNormLinear(nn.Module):
    def __init__(self, in_features, out_features):
        super(SimpleNormLinear, self).__init__()
        self.linear = nn.Linear(in_features, out_features, bias=True)  # Norm 제거

    def forward(self, x):
        return self.linear(x)

# %%
class LearnableMask(nn.Module):
    def __init__(self, num_layers):
        super(LearnableMask, self).__init__()
        self.mask_logits = nn.Parameter(torch.randn(num_layers))  # Learnable mask weights

    def forward(self):
        # Differentiable Gumbel-Softmax Sampling
        tau = 1.0  # Temperature parameter
        gumbel_noise = -torch.log(-torch.log(torch.rand_like(self.mask_logits)))  # Gumbel noise
        mask_probs = F.softmax((self.mask_logits + gumbel_noise) / tau, dim=0)
        return mask_probs

# %%
class PrunedLevitStage(nn.Module):
    def __init__(self, dim, out_dim, num_heads, num_blocks, downsample=True):
        super(PrunedLevitStage, self).__init__()
        self.downsample = CNNDownsample(dim, out_dim) if downsample else nn.Identity()
        self.blocks = nn.ModuleList([LevitBlock(out_dim, num_heads) for _ in range(num_blocks)])
        self.learnable_mask = LearnableMask(num_blocks)

    def forward(self, x):
        x = self.downsample(x)

        if self.training:  # Gumbel-Softmax 사용
            mask_probs = self.learnable_mask()
        else:  # Deterministic Mask
            mask_probs = F.softmax(self.learnable_mask.mask_logits, dim=0).detach()

        for i, block in enumerate(self.blocks):
            if mask_probs[i] > 0.5:
                x = block(x)

        return x

# %%
class PrunedLevitDistilled(nn.Module):
    def __init__(self, num_classes=9):
        super(PrunedLevitDistilled, self).__init__()

        self.stem = Stem16()
        self.stage1 = PrunedLevitStage(dim=256, out_dim=256, num_heads=4, num_blocks=6, downsample=False)
        self.stage2 = PrunedLevitStage(dim=256, out_dim=384, num_heads=6, num_blocks=6, downsample=True)

        self.conv1x1 = nn.Sequential(
            nn.Conv2d(384, 512, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        self.head = SimpleNormLinear(in_features=512, out_features=num_classes)
        self.head_dist = SimpleNormLinear(in_features=512, out_features=num_classes)

    def forward(self, x):
        x = self.stem(x)

        B, C, H, W = x.shape
        x = x.view(B, C, -1).transpose(1, 2)
        x = self.stage1(x)
        x = self.stage2(x)

        H = W = int(x.shape[1]**0.5)
        x = x.transpose(1, 2).view(B, 384, H, W)

        x = self.conv1x1(x)

        x = torch.mean(x, dim=(2, 3))
        out = self.head(x)
        out_dist = self.head_dist(x)
        return out

# %%
model = PrunedLevitDistilled(num_classes=9)
print(model)
# Out:
# PrunedLevitDistilled(
#   (stem): Stem16(
#     (conv1): ConvNorm(
#       (linear): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act1): Hardswish()
#     (conv2): ConvNorm(
#       (linear): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act2): Hardswish()
#     (conv3): ConvNorm(
#       (linear): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act3): Hardswish()
#     (conv4): ConvNorm(
#       (linear): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stage1): PrunedLevitStage(
#     (downsample): Identity()
#     (blocks): ModuleList(
#       (0-5): 6 x LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#     (learnable_mask): LearnableMask()
#   )
#   (stage2): PrunedLevitStage(
#     (downsample): CNNDownsample(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): Hardswish()
#     )
#     (blocks): ModuleList(
#       (0-5): 6 x LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#     (learnable_mask): LearnableMask()
#   )
#   (conv1x1): Sequential(
#     (0): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (head): SimpleNormLinear(
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (head_dist): SimpleNormLinear(
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
print(summary(model, input_size=(32, 3, 224, 224), verbose=2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# PrunedLevitDistilled                     [32, 9]                   --
# ├─Stem16: 1-1                            [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                         ├─864
# │    └─conv1.bn.weight                                             ├─32
# │    └─conv1.bn.bias                                               ├─32
# │    └─conv2.linear.weight                                         ├─18,432
# │    └─conv2.bn.weight                                             ├─64
# │    └─conv2.bn.bias                                               ├─64
# │    └─conv3.linear.weight                                         ├─73,728
# │    └─conv3.bn.weight                                             ├─128
# │    └─conv3.bn.bias                                               ├─128
# │    └─conv4.linear.weight                                         ├─294,912
# │    └─conv4.bn.weight                                             ├─256
# │    └─conv4.bn.bias                                               └─256
# │    └─ConvNorm: 2-1                     [32, 32, 112, 112]        --
# │    │    └─linear.weight                                          ├─864
# │    │    └─bn.weight                                              ├─32
# │    │    └─bn.bias                                                └─32
# │    │    └─Conv2d: 3-1                  [32, 32, 112, 112]        864
# │    │    │    └─weight                                            └─864
# │    │    └─BatchNorm2d: 3-2             [32, 32, 112, 112]        64
# │    │    │    └─weight                                            ├─32
# │    │    │    └─bias                                              └─32
# │    └─Hardswish: 2-2                    [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                     [32, 64, 56, 56]          --
# │    │    └─linear.weight                                          ├─18,432
# │    │    └─bn.weight                                              ├─64
# │    │    └─bn.bias                                                └─64
# │    │    └─Conv2d: 3-3                  [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                            └─18,432
# │    │    └─BatchNorm2d: 3-4             [32, 64, 56, 56]          128
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    └─Hardswish: 2-4                    [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                     [32, 128, 28, 28]         --
# │    │    └─linear.weight                                          ├─73,728
# │    │    └─bn.weight                                              ├─128
# │    │    └─bn.bias                                                └─128
# │    │    └─Conv2d: 3-5                  [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                            └─73,728
# │    │    └─BatchNorm2d: 3-6             [32, 128, 28, 28]         256
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    └─Hardswish: 2-6                    [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                     [32, 256, 14, 14]         --
# │    │    └─linear.weight                                          ├─294,912
# │    │    └─bn.weight                                              ├─256
# │    │    └─bn.bias                                                └─256
# │    │    └─Conv2d: 3-7                  [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                            └─294,912
# │    │    └─BatchNorm2d: 3-8             [32, 256, 14, 14]         512
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# ├─PrunedLevitStage: 1-2                  [32, 196, 256]            3,167,238
# │    └─blocks.0.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.1.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.2.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.3.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.4.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.5.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─256
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─Identity: 2-8                     [32, 196, 256]            --
# ├─PrunedLevitStage: 1-3                  [32, 49, 384]             7,110,150
# │    └─downsample.conv.weight                                      ├─884,736
# │    └─downsample.conv.bias                                        ├─384
# │    └─blocks.0.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.1.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.2.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.3.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.4.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.5.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─384
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─CNNDownsample: 2-9                [32, 49, 384]             --
# │    │    └─conv.weight                                            ├─884,736
# │    │    └─conv.bias                                              └─384
# │    │    └─Conv2d: 3-9                  [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                            ├─884,736
# │    │    │    └─bias                                              └─384
# │    │    └─Hardswish: 3-10              [32, 384, 7, 7]           --
# ├─Sequential: 1-4                        [32, 512, 7, 7]           --
# │    └─0.weight                                                    ├─196,608
# │    └─0.bias                                                      ├─512
# │    └─1.weight                                                    ├─512
# │    └─1.bias                                                      └─512
# │    └─Conv2d: 2-10                      [32, 512, 7, 7]           197,120
# │    │    └─weight                                                 ├─196,608
# │    │    └─bias                                                   └─512
# │    └─BatchNorm2d: 2-11                 [32, 512, 7, 7]           1,024
# │    │    └─weight                                                 ├─512
# │    │    └─bias                                                   └─512
# │    └─ReLU: 2-12                        [32, 512, 7, 7]           --
# ├─SimpleNormLinear: 1-5                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-13                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ├─SimpleNormLinear: 1-6                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-14                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ==========================================================================================
# Total params: 11,758,782
# Trainable params: 11,758,782
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 7.59
# ==========================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 403.02
# Params size (MB): 5.93
# Estimated Total Size (MB): 428.21
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# PrunedLevitDistilled                     [32, 9]                   --
# ├─Stem16: 1-1                            [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                         ├─864
# │    └─conv1.bn.weight                                             ├─32
# │    └─conv1.bn.bias                                               ├─32
# │    └─conv2.linear.weight                                         ├─18,432
# │    └─conv2.bn.weight                                             ├─64
# │    └─conv2.bn.bias                                               ├─64
# │    └─conv3.linear.weight                                         ├─73,728
# │    └─conv3.bn.weight                                             ├─128
# │    └─conv3.bn.bias                                               ├─128
# │    └─conv4.linear.weight                                         ├─294,912
# │    └─conv4.bn.weight                                             ├─256
# │    └─conv4.bn.bias                                               └─256
# │    └─ConvNorm: 2-1                     [32, 32, 112, 112]        --
# │    │    └─linear.weight                                          ├─864
# │    │    └─bn.weight                                              ├─32
# │    │    └─bn.bias                                                └─32
# │    │    └─Conv2d: 3-1                  [32, 32, 112, 112]        864
# │    │    │    └─weight                                            └─864
# │    │    └─BatchNorm2d: 3-2             [32, 32, 112, 112]        64
# │    │    │    └─weight                                            ├─32
# │    │    │    └─bias                                              └─32
# │    └─Hardswish: 2-2                    [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                     [32, 64, 56, 56]          --
# │    │    └─linear.weight                                          ├─18,432
# │    │    └─bn.weight                                              ├─64
# │    │    └─bn.bias                                                └─64
# │    │    └─Conv2d: 3-3                  [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                            └─18,432
# │    │    └─BatchNorm2d: 3-4             [32, 64, 56, 56]          128
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    └─Hardswish: 2-4                    [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                     [32, 128, 28, 28]         --
# │    │    └─linear.weight                                          ├─73,728
# │    │    └─bn.weight                                              ├─128
# │    │    └─bn.bias                                                └─128
# │    │    └─Conv2d: 3-5                  [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                            └─73,728
# │    │    └─BatchNorm2d: 3-6             [32, 128, 28, 28]         256
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    └─Hardswish: 2-6                    [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                     [32, 256, 14, 14]         --
# │    │    └─linear.weight                                          ├─294,912
# │    │    └─bn.weight                                              ├─256
# │    │    └─bn.bias                                                └─256
# │    │    └─Conv2d: 3-7                  [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                            └─294,912
# │    │    └─BatchNorm2d: 3-8             [32, 256, 14, 14]         512
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# ├─PrunedLevitStage: 1-2                  [32, 196, 256]            3,167,238
# │    └─blocks.0.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.1.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.2.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.3.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.4.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.5.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─256
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─Identity: 2-8                     [32, 196, 256]            --
# ├─PrunedLevitStage: 1-3                  [32, 49, 384]             7,110,150
# │    └─downsample.conv.weight                                      ├─884,736
# │    └─downsample.conv.bias                                        ├─384
# │    └─blocks.0.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.1.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.2.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.3.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.4.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.5.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─384
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─CNNDownsample: 2-9                [32, 49, 384]             --
# │    │    └─conv.weight                                            ├─884,736
# │    │    └─conv.bias                                              └─384
# │    │    └─Conv2d: 3-9                  [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                            ├─884,736
# │    │    │    └─bias                                              └─384
# │    │    └─Hardswish: 3-10              [32, 384, 7, 7]           --
# ├─Sequential: 1-4                        [32, 512, 7, 7]           --
# │    └─0.weight                                                    ├─196,608
# │    └─0.bias                                                      ├─512
# │    └─1.weight                                                    ├─512
# │    └─1.bias                                                      └─512
# │    └─Conv2d: 2-10                      [32, 512, 7, 7]           197,120
# │    │    └─weight                                                 ├─196,608
# │    │    └─bias                                                   └─512
# │    └─BatchNorm2d: 2-11                 [32, 512, 7, 7]           1,024
# │    │    └─weight                                                 ├─512
# │    │    └─bias                                                   └─512
# │    └─ReLU: 2-12                        [32, 512, 7, 7]           --
# ├─SimpleNormLinear: 1-5                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-13                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ├─SimpleNormLinear: 1-6                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-14                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ==========================================================================================
# Total params: 11,758,782
# Trainable params: 11,758,782
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 7.59
# ==========================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 403.02
# Params size (MB): 5.93
# Estimated Total Size (MB): 428.21
# ==========================================================================================

# %%
import torch.nn.init as init

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # CUDA 연산 시 동일한 결과 보장
    torch.cuda.manual_seed_all(seed)  # 멀티-GPU 환경에서 동일한 결과 보장
    torch.backends.cudnn.deterministic = True  # CuDNN 연산을 deterministic하게 설정
    torch.backends.cudnn.benchmark = False  # 연산 속도를 희생하고 일관된 연산을 수행

def initialize_weights(m):
    if isinstance(m, nn.Conv2d):  # Conv 레이어 초기화
        init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            init.constant_(m.bias, 0)
    elif isinstance(m, nn.Linear):  # Linear 레이어 초기화
        init.xavier_uniform_(m.weight)
        if m.bias is not None:
            init.constant_(m.bias, 0)
    elif isinstance(m, nn.BatchNorm2d) or isinstance(m, nn.BatchNorm1d):  # BatchNorm 초기화
        init.constant_(m.weight, 1)
        init.constant_(m.bias, 0)

set_seed(42)  # 랜덤 시드 고정
model.apply(initialize_weights)
# Out:
# PrunedLevitDistilled(
#   (stem): Stem16(
#     (conv1): ConvNorm(
#       (linear): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act1): Hardswish()
#     (conv2): ConvNorm(
#       (linear): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act2): Hardswish()
#     (conv3): ConvNorm(
#       (linear): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act3): Hardswish()
#     (conv4): ConvNorm(
#       (linear): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stage1): PrunedLevitStage(
#     (downsample): Identity()
#     (blocks): ModuleList(
#       (0-5): 6 x LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=256, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=512, out_features=256, bias=False)
#             (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#     (learnable_mask): LearnableMask()
#   )
#   (stage2): PrunedLevitStage(
#     (downsample): CNNDownsample(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): Hardswish()
#     )
#     (blocks): ModuleList(
#       (0-5): 6 x LevitBlock(
#         (attn): Attention(
#           (qkv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1152, bias=False)
#             (bn): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (proj): Sequential(
#             (0): Hardswish()
#             (1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (drop_path1): Identity()
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.5, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path2): Identity()
#       )
#     )
#     (learnable_mask): LearnableMask()
#   )
#   (conv1x1): Sequential(
#     (0): Conv2d(384, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (head): SimpleNormLinear(
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
#   (head_dist): SimpleNormLinear(
#     (linear): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

batch_size = 32
learning_rate = 5e-4
decay_rate = 1e-6
num_epochs = 30

# %%
train_dir = 'train/NCT-CRC-HE-100K'

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
dataset = datasets.ImageFolder(root=train_dir, transform=transform)

# %%
import json

with open("./default_index_dict.json", "r") as f:
    index_dict = json.load(f)
load_train_idx = index_dict["train_idx"]
load_val_idx = index_dict["val_idx"]
load_test_idx = index_dict["test_idx"]

# %%
train_data = Subset(dataset, load_train_idx)
val_data = Subset(dataset, load_val_idx)
test_data = Subset(dataset, load_test_idx)

# %%
g = torch.Generator()
g.manual_seed(42)  # 전체 난수 시퀀스를 고정

train_loader = DataLoader(
    train_data, batch_size=batch_size, shuffle=True, num_workers=4,
    worker_init_fn=lambda worker_id: np.random.seed(42 + worker_id),
    generator=g  # 🔹 DataLoader의 난수 시퀀스를 고정
)

val_loader = DataLoader(
    val_data, batch_size=batch_size, shuffle=False, num_workers=4,
    worker_init_fn=lambda worker_id: np.random.seed(42 + worker_id),
    generator=g
)

test_loader = DataLoader(
    test_data, batch_size=batch_size, shuffle=False, num_workers=4,
    worker_init_fn=lambda worker_id: np.random.seed(42 + worker_id),
    generator=g
)
print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Train set size: 70000
# Validation set size: 15000
# Test set size: 15000

# %%
# Show one example per class from the training dataset
import matplotlib.pyplot as plt

# Prepare a dictionary to store one example per class
class_examples = {}
for images, labels in train_loader:
    for img, label in zip(images, labels):
        label = label.item()
        if label not in class_examples:
            class_examples[label] = img
        # Stop if we already have one example for each class
        if len(class_examples) == len(dataset.classes):
            break
    if len(class_examples) == len(dataset.classes):
        break

# Display the images and their labels
figure = plt.figure(figsize=(8, 8))
cols = 3  # You can adjust the number of columns as needed
rows = (len(dataset.classes) + cols - 1) // cols  # Calculate required rows
for i, (label, img) in enumerate(class_examples.items(), start=1):
    figure.add_subplot(rows, cols, i)
    plt.title(dataset.classes[label])
    plt.axis("off")
    plt.imshow(img.permute(1, 2, 0).numpy())  # Convert tensor to numpy for display
plt.show()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in tqdm(train_loader, desc="Training"):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {accuracy:.2f}%")
    train_losses.append(epoch_loss)
    train_accuracies.append(accuracy)

# %%
def evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            # Save all labels and predictions for balanced accuracy
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    balanced_acc = balanced_accuracy_score(all_labels, all_predictions)

    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")

    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

# %%
def measure_inference_time(model, data_loader, device):
    model.eval()
    times = []

    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            start_time = torch.cuda.Event(enable_timing=True)
            end_time = torch.cuda.Event(enable_timing=True)

            start_time.record()
            _ = model(inputs)  # inference 수행
            end_time.record()

            # 시간 측정
            torch.cuda.synchronize()  # CUDA에서 모든 커널이 완료될 때까지 대기
            elapsed_time = start_time.elapsed_time(end_time)  # 밀리초 단위로 반환
            times.append(elapsed_time)

    # 통계량 계산
    times_np = np.array(times)
    total_inferences = len(times_np)
    avg_time = np.mean(times_np)
    std_dev = np.std(times_np)
    max_time = np.max(times_np)
    min_time = np.min(times_np)

    # 결과 출력
    print(f"Inference Time Measurement Results:")
    print(f"Total Inferences: {total_inferences}")
    print(f"Average Time: {avg_time:.2f} ms")
    print(f"Standard Deviation: {std_dev:.2f} ms")
    print(f"Maximum Time: {max_time:.2f} ms")
    print(f"Minimum Time: {min_time:.2f} ms")

    return times

# %%
for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    train(model, train_loader, criterion, optimizer, device)
    evaluate(model, val_loader, criterion, device, phase="Validation")
# Out:
# Epoch 1/30
# Training: 100%|██████████| 2188/2188 [00:51<00:00, 42.70it/s]
# Train Loss: 0.5714, Train Accuracy: 79.45%
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.43it/s]
# Validation Loss: 0.9557, Validation Accuracy: 63.37%
# Balanced Accuracy: 0.6383
#
# Epoch 2/30
# Training: 100%|██████████| 2188/2188 [00:50<00:00, 43.09it/s]
# Train Loss: 0.2627, Train Accuracy: 91.10%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 64.56it/s]
# Validation Loss: 1.3012, Validation Accuracy: 63.25%
# Balanced Accuracy: 0.6406
#
# Epoch 3/30
# Training: 100%|██████████| 2188/2188 [00:50<00:00, 43.28it/s]
# Train Loss: 0.1827, Train Accuracy: 93.86%
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.96it/s]
# Validation Loss: 1.7180, Validation Accuracy: 68.83%
# Balanced Accuracy: 0.6681
#
# Epoch 4/30
# Training: 100%|██████████| 2188/2188 [00:50<00:00, 43.09it/s]
# Train Loss: 0.1457, Train Accuracy: 95.08%
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.47it/s]
# Validation Loss: 1.1272, Validation Accuracy: 74.89%
# Balanced Accuracy: 0.7317
#
# Epoch 5/30
# Training: 100%|██████████| 2188/2188 [00:51<00:00, 42.37it/s]
# Train Loss: 0.1246, Train Accuracy: 95.86%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 65.89it/s]
# Validation Loss: 0.6553, Validation Accuracy: 77.59%
# Balanced Accuracy: 0.7554
#
# Epoch 6/30
# Training: 100%|██████████| 2188/2188 [00:51<00:00, 42.57it/s]
# Train Loss: 0.1035, Train Accuracy: 96.54%
# Validation: 100%|██████████| 469/469 [00:06<00:00, 69.34it/s]
# Validation Loss: 1.1189, Validation Accuracy: 72.82%
# Balanced Accuracy: 0.7205
#
# Epoch 7/30
# Training: 100%|██████████| 2188/2188 [00:51<00:00, 42.81it/s]
# Train Loss: 0.0922, Train Accuracy: 96.85%
# Validation: 100%|██████████| 469/469 [00:06<00:00, 70.29it/s]
# Validation Loss: 8.2045, Validation Accuracy: 25.29%
# Balanced Accuracy: 0.2627
#
# Epoch 8/30
# Training: 100%|██████████| 2188/2188 [00:50<00:00, 43.00it/s]
# Train Loss: 0.0823, Train Accuracy: 97.24%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 66.35it/s]
# Validation Loss: 0.8043, Validation Accuracy: 72.45%
# Balanced Accuracy: 0.7295
#
# Epoch 9/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 40.37it/s]
# Train Loss: 0.0743, Train Accuracy: 97.44%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.17it/s]
# Validation Loss: 0.1159, Validation Accuracy: 96.17%
# Balanced Accuracy: 0.9577
#
# Epoch 10/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 40.24it/s]
# Train Loss: 0.0658, Train Accuracy: 97.81%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.98it/s]
# Validation Loss: 0.1799, Validation Accuracy: 93.61%
# Balanced Accuracy: 0.9314
#
# Epoch 11/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.82it/s]
# Train Loss: 0.0603, Train Accuracy: 97.95%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 64.89it/s]
# Validation Loss: 0.9465, Validation Accuracy: 73.19%
# Balanced Accuracy: 0.7253
#
# Epoch 12/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 40.12it/s]
# Train Loss: 0.0542, Train Accuracy: 98.13%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 64.91it/s]
# Validation Loss: 0.4754, Validation Accuracy: 83.55%
# Balanced Accuracy: 0.8307
#
# Epoch 13/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.84it/s]
# Train Loss: 0.0483, Train Accuracy: 98.39%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 65.06it/s]
# Validation Loss: 0.4328, Validation Accuracy: 85.58%
# Balanced Accuracy: 0.8471
#
# Epoch 14/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.91it/s]
# Train Loss: 0.0467, Train Accuracy: 98.45%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 65.92it/s]
# Validation Loss: 0.1394, Validation Accuracy: 94.96%
# Balanced Accuracy: 0.9465
#
# Epoch 15/30
# Training: 100%|██████████| 2188/2188 [00:55<00:00, 39.75it/s]
# Train Loss: 0.0416, Train Accuracy: 98.57%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 66.62it/s]
# Validation Loss: 0.1067, Validation Accuracy: 96.53%
# Balanced Accuracy: 0.9640
#
# Epoch 16/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.85it/s]
# Train Loss: 0.0382, Train Accuracy: 98.74%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 66.37it/s]
# Validation Loss: 0.0433, Validation Accuracy: 98.65%
# Balanced Accuracy: 0.9863
#
# Epoch 17/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.89it/s]
# Train Loss: 0.0369, Train Accuracy: 98.76%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 65.94it/s]
# Validation Loss: 2.3774, Validation Accuracy: 65.61%
# Balanced Accuracy: 0.6344
#
# Epoch 18/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 40.24it/s]
# Train Loss: 0.0310, Train Accuracy: 98.95%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 65.66it/s]
# Validation Loss: 1.3602, Validation Accuracy: 70.86%
# Balanced Accuracy: 0.7048
#
# Epoch 19/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.80it/s]
# Train Loss: 0.0300, Train Accuracy: 98.99%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 66.53it/s]
# Validation Loss: 0.6111, Validation Accuracy: 83.28%
# Balanced Accuracy: 0.8203
#
# Epoch 20/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 40.08it/s]
# Train Loss: 0.0276, Train Accuracy: 99.07%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 64.03it/s]
# Validation Loss: 0.0564, Validation Accuracy: 98.13%
# Balanced Accuracy: 0.9801
#
# Epoch 21/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.83it/s]
# Train Loss: 0.0247, Train Accuracy: 99.15%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.68it/s]
# Validation Loss: 5.2955, Validation Accuracy: 40.00%
# Balanced Accuracy: 0.4080
#
# Epoch 22/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 40.21it/s]
# Train Loss: 0.0262, Train Accuracy: 99.12%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.76it/s]
# Validation Loss: 0.3058, Validation Accuracy: 90.11%
# Balanced Accuracy: 0.8945
#
# Epoch 23/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.95it/s]
# Train Loss: 0.0233, Train Accuracy: 99.23%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.62it/s]
# Validation Loss: 0.0567, Validation Accuracy: 98.15%
# Balanced Accuracy: 0.9806
#
# Epoch 24/30
# Training: 100%|██████████| 2188/2188 [00:55<00:00, 39.56it/s]
# Train Loss: 0.0218, Train Accuracy: 99.27%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.01it/s]
# Validation Loss: 0.1706, Validation Accuracy: 95.00%
# Balanced Accuracy: 0.9478
#
# Epoch 25/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 40.04it/s]
# Train Loss: 0.0205, Train Accuracy: 99.30%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.49it/s]
# Validation Loss: 0.0371, Validation Accuracy: 98.75%
# Balanced Accuracy: 0.9876
#
# Epoch 26/30
# Training: 100%|██████████| 2188/2188 [00:55<00:00, 39.56it/s]
# Train Loss: 0.0195, Train Accuracy: 99.32%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.87it/s]
# Validation Loss: 0.8387, Validation Accuracy: 82.21%
# Balanced Accuracy: 0.8002
#
# Epoch 27/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.89it/s]
# Train Loss: 0.0177, Train Accuracy: 99.39%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.22it/s]
# Validation Loss: 0.0714, Validation Accuracy: 97.77%
# Balanced Accuracy: 0.9773
#
# Epoch 28/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.99it/s]
# Train Loss: 0.0173, Train Accuracy: 99.39%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 64.71it/s]
# Validation Loss: 0.2543, Validation Accuracy: 93.43%
# Balanced Accuracy: 0.9318
#
# Epoch 29/30
# Training: 100%|██████████| 2188/2188 [00:55<00:00, 39.47it/s]
# Train Loss: 0.0163, Train Accuracy: 99.43%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 63.36it/s]
# Validation Loss: 0.0325, Validation Accuracy: 98.97%
# Balanced Accuracy: 0.9896
#
# Epoch 30/30
# Training: 100%|██████████| 2188/2188 [00:54<00:00, 39.87it/s]
# Train Loss: 0.0151, Train Accuracy: 99.50%
# Validation: 100%|██████████| 469/469 [00:07<00:00, 62.94it/s]
# Validation Loss: 0.5140, Validation Accuracy: 84.56%
# Balanced Accuracy: 0.8431

# %%
print("\nFinal Test Evaluation")
evaluate(model, test_loader, criterion, device, phase="Test")
# Out:
# Final Test Evaluation
# Test: 100%|██████████| 469/469 [00:06<00:00, 67.09it/s]
# Test Loss: 0.5315, Test Accuracy: 84.35%
# Balanced Accuracy: 0.8402

# %%
print(summary(model, input_size=(32, 3, 224, 224), verbose=2))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# PrunedLevitDistilled                     [32, 9]                   --
# ├─Stem16: 1-1                            [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                         ├─864
# │    └─conv1.bn.weight                                             ├─32
# │    └─conv1.bn.bias                                               ├─32
# │    └─conv2.linear.weight                                         ├─18,432
# │    └─conv2.bn.weight                                             ├─64
# │    └─conv2.bn.bias                                               ├─64
# │    └─conv3.linear.weight                                         ├─73,728
# │    └─conv3.bn.weight                                             ├─128
# │    └─conv3.bn.bias                                               ├─128
# │    └─conv4.linear.weight                                         ├─294,912
# │    └─conv4.bn.weight                                             ├─256
# │    └─conv4.bn.bias                                               └─256
# │    └─ConvNorm: 2-1                     [32, 32, 112, 112]        --
# │    │    └─linear.weight                                          ├─864
# │    │    └─bn.weight                                              ├─32
# │    │    └─bn.bias                                                └─32
# │    │    └─Conv2d: 3-1                  [32, 32, 112, 112]        864
# │    │    │    └─weight                                            └─864
# │    │    └─BatchNorm2d: 3-2             [32, 32, 112, 112]        64
# │    │    │    └─weight                                            ├─32
# │    │    │    └─bias                                              └─32
# │    └─Hardswish: 2-2                    [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                     [32, 64, 56, 56]          --
# │    │    └─linear.weight                                          ├─18,432
# │    │    └─bn.weight                                              ├─64
# │    │    └─bn.bias                                                └─64
# │    │    └─Conv2d: 3-3                  [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                            └─18,432
# │    │    └─BatchNorm2d: 3-4             [32, 64, 56, 56]          128
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    └─Hardswish: 2-4                    [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                     [32, 128, 28, 28]         --
# │    │    └─linear.weight                                          ├─73,728
# │    │    └─bn.weight                                              ├─128
# │    │    └─bn.bias                                                └─128
# │    │    └─Conv2d: 3-5                  [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                            └─73,728
# │    │    └─BatchNorm2d: 3-6             [32, 128, 28, 28]         256
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    └─Hardswish: 2-6                    [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                     [32, 256, 14, 14]         --
# │    │    └─linear.weight                                          ├─294,912
# │    │    └─bn.weight                                              ├─256
# │    │    └─bn.bias                                                └─256
# │    │    └─Conv2d: 3-7                  [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                            └─294,912
# │    │    └─BatchNorm2d: 3-8             [32, 256, 14, 14]         512
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# ├─PrunedLevitStage: 1-2                  [32, 196, 256]            3,167,238
# │    └─blocks.0.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.1.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.2.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.3.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.4.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.5.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─256
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─Identity: 2-8                     [32, 196, 256]            --
# ├─PrunedLevitStage: 1-3                  [32, 49, 384]             7,110,150
# │    └─downsample.conv.weight                                      ├─884,736
# │    └─downsample.conv.bias                                        ├─384
# │    └─blocks.0.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.1.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.2.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.3.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.4.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.5.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─384
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─CNNDownsample: 2-9                [32, 49, 384]             --
# │    │    └─conv.weight                                            ├─884,736
# │    │    └─conv.bias                                              └─384
# │    │    └─Conv2d: 3-9                  [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                            ├─884,736
# │    │    │    └─bias                                              └─384
# │    │    └─Hardswish: 3-10              [32, 384, 7, 7]           --
# ├─Sequential: 1-4                        [32, 512, 7, 7]           --
# │    └─0.weight                                                    ├─196,608
# │    └─0.bias                                                      ├─512
# │    └─1.weight                                                    ├─512
# │    └─1.bias                                                      └─512
# │    └─Conv2d: 2-10                      [32, 512, 7, 7]           197,120
# │    │    └─weight                                                 ├─196,608
# │    │    └─bias                                                   └─512
# │    └─BatchNorm2d: 2-11                 [32, 512, 7, 7]           1,024
# │    │    └─weight                                                 ├─512
# │    │    └─bias                                                   └─512
# │    └─ReLU: 2-12                        [32, 512, 7, 7]           --
# ├─SimpleNormLinear: 1-5                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-13                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ├─SimpleNormLinear: 1-6                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-14                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ==========================================================================================
# Total params: 11,758,782
# Trainable params: 11,758,782
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 7.59
# ==========================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 403.02
# Params size (MB): 5.93
# Estimated Total Size (MB): 428.21
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# PrunedLevitDistilled                     [32, 9]                   --
# ├─Stem16: 1-1                            [32, 256, 14, 14]         --
# │    └─conv1.linear.weight                                         ├─864
# │    └─conv1.bn.weight                                             ├─32
# │    └─conv1.bn.bias                                               ├─32
# │    └─conv2.linear.weight                                         ├─18,432
# │    └─conv2.bn.weight                                             ├─64
# │    └─conv2.bn.bias                                               ├─64
# │    └─conv3.linear.weight                                         ├─73,728
# │    └─conv3.bn.weight                                             ├─128
# │    └─conv3.bn.bias                                               ├─128
# │    └─conv4.linear.weight                                         ├─294,912
# │    └─conv4.bn.weight                                             ├─256
# │    └─conv4.bn.bias                                               └─256
# │    └─ConvNorm: 2-1                     [32, 32, 112, 112]        --
# │    │    └─linear.weight                                          ├─864
# │    │    └─bn.weight                                              ├─32
# │    │    └─bn.bias                                                └─32
# │    │    └─Conv2d: 3-1                  [32, 32, 112, 112]        864
# │    │    │    └─weight                                            └─864
# │    │    └─BatchNorm2d: 3-2             [32, 32, 112, 112]        64
# │    │    │    └─weight                                            ├─32
# │    │    │    └─bias                                              └─32
# │    └─Hardswish: 2-2                    [32, 32, 112, 112]        --
# │    └─ConvNorm: 2-3                     [32, 64, 56, 56]          --
# │    │    └─linear.weight                                          ├─18,432
# │    │    └─bn.weight                                              ├─64
# │    │    └─bn.bias                                                └─64
# │    │    └─Conv2d: 3-3                  [32, 64, 56, 56]          18,432
# │    │    │    └─weight                                            └─18,432
# │    │    └─BatchNorm2d: 3-4             [32, 64, 56, 56]          128
# │    │    │    └─weight                                            ├─64
# │    │    │    └─bias                                              └─64
# │    └─Hardswish: 2-4                    [32, 64, 56, 56]          --
# │    └─ConvNorm: 2-5                     [32, 128, 28, 28]         --
# │    │    └─linear.weight                                          ├─73,728
# │    │    └─bn.weight                                              ├─128
# │    │    └─bn.bias                                                └─128
# │    │    └─Conv2d: 3-5                  [32, 128, 28, 28]         73,728
# │    │    │    └─weight                                            └─73,728
# │    │    └─BatchNorm2d: 3-6             [32, 128, 28, 28]         256
# │    │    │    └─weight                                            ├─128
# │    │    │    └─bias                                              └─128
# │    └─Hardswish: 2-6                    [32, 128, 28, 28]         --
# │    └─ConvNorm: 2-7                     [32, 256, 14, 14]         --
# │    │    └─linear.weight                                          ├─294,912
# │    │    └─bn.weight                                              ├─256
# │    │    └─bn.bias                                                └─256
# │    │    └─Conv2d: 3-7                  [32, 256, 14, 14]         294,912
# │    │    │    └─weight                                            └─294,912
# │    │    └─BatchNorm2d: 3-8             [32, 256, 14, 14]         512
# │    │    │    └─weight                                            ├─256
# │    │    │    └─bias                                              └─256
# ├─PrunedLevitStage: 1-2                  [32, 196, 256]            3,167,238
# │    └─blocks.0.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.1.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.2.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.3.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.4.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─256
# │    └─blocks.5.attn.qkv.linear.weight                             ├─196,608
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─768
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─768
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─65,536
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─256
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─256
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─512
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─512
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─131,072
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─256
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─256
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─Identity: 2-8                     [32, 196, 256]            --
# ├─PrunedLevitStage: 1-3                  [32, 49, 384]             7,110,150
# │    └─downsample.conv.weight                                      ├─884,736
# │    └─downsample.conv.bias                                        ├─384
# │    └─blocks.0.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.0.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.0.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.0.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.0.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.0.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.0.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.0.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.0.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.0.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.0.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.1.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.1.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.1.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.1.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.1.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.1.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.1.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.1.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.1.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.1.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.1.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.2.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.2.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.2.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.2.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.2.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.2.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.2.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.2.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.2.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.2.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.2.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.3.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.3.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.3.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.3.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.3.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.3.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.3.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.3.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.3.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.3.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.3.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.4.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.4.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.4.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.4.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.4.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.4.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.4.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.4.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.4.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.4.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.4.mlp.ln2.bn.bias                                    ├─384
# │    └─blocks.5.attn.qkv.linear.weight                             ├─442,368
# │    └─blocks.5.attn.qkv.bn.weight                                 ├─1,152
# │    └─blocks.5.attn.qkv.bn.bias                                   ├─1,152
# │    └─blocks.5.attn.proj.1.linear.weight                           ├─147,456
# │    └─blocks.5.attn.proj.1.bn.weight                              ├─384
# │    └─blocks.5.attn.proj.1.bn.bias                                ├─384
# │    └─blocks.5.mlp.ln1.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln1.bn.weight                                  ├─768
# │    └─blocks.5.mlp.ln1.bn.bias                                    ├─768
# │    └─blocks.5.mlp.ln2.linear.weight                              ├─294,912
# │    └─blocks.5.mlp.ln2.bn.weight                                  ├─384
# │    └─blocks.5.mlp.ln2.bn.bias                                    ├─384
# │    └─learnable_mask.mask_logits                                  └─6
# │    └─CNNDownsample: 2-9                [32, 49, 384]             --
# │    │    └─conv.weight                                            ├─884,736
# │    │    └─conv.bias                                              └─384
# │    │    └─Conv2d: 3-9                  [32, 384, 7, 7]           885,120
# │    │    │    └─weight                                            ├─884,736
# │    │    │    └─bias                                              └─384
# │    │    └─Hardswish: 3-10              [32, 384, 7, 7]           --
# ├─Sequential: 1-4                        [32, 512, 7, 7]           --
# │    └─0.weight                                                    ├─196,608
# │    └─0.bias                                                      ├─512
# │    └─1.weight                                                    ├─512
# │    └─1.bias                                                      └─512
# │    └─Conv2d: 2-10                      [32, 512, 7, 7]           197,120
# │    │    └─weight                                                 ├─196,608
# │    │    └─bias                                                   └─512
# │    └─BatchNorm2d: 2-11                 [32, 512, 7, 7]           1,024
# │    │    └─weight                                                 ├─512
# │    │    └─bias                                                   └─512
# │    └─ReLU: 2-12                        [32, 512, 7, 7]           --
# ├─SimpleNormLinear: 1-5                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-13                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ├─SimpleNormLinear: 1-6                  [32, 9]                   --
# │    └─linear.weight                                               ├─4,608
# │    └─linear.bias                                                 └─9
# │    └─Linear: 2-14                      [32, 9]                   4,617
# │    │    └─weight                                                 ├─4,608
# │    │    └─bias                                                   └─9
# ==========================================================================================
# Total params: 11,758,782
# Trainable params: 11,758,782
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 7.59
# ==========================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 403.02
# Params size (MB): 5.93
# Estimated Total Size (MB): 428.21
# ==========================================================================================

# %%
print("train_loss length : ", len(train_losses))
print("train_acc length : ", len(train_accuracies))
print("val_loss length : ", len(val_losses))
print("val_acc length : ", len(val_accuracies))

print("val_adj : ", len(val_losses[:num_epochs]))
print("val_acc_adj : ", len(val_accuracies[:num_epochs]))
# Out:
# train_loss length :  30
# train_acc length :  30
# val_loss length :  31
# val_acc length :  31
# val_adj :  30
# val_acc_adj :  30

# %%
# Plot the metrics
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 5))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses[:num_epochs], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label="Train Accuracy")
plt.plot(epochs, val_accuracies[:num_epochs], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
times = measure_inference_time(model, test_loader, device)
# Out:
# Inference Time Measurement Results:
# Total Inferences: 469
# Average Time: 2.85 ms
# Standard Deviation: 0.47 ms
# Maximum Time: 6.06 ms
# Minimum Time: 2.53 ms

# %%
from torch import profiler

dummy_input = torch.randn(32, 3, 224, 224).cuda()

# Profiling inference
with profiler.profile(
    activities=[
       profiler.ProfilerActivity.CPU,
        profiler.ProfilerActivity.CUDA,  # Include if using GPU
    ],
    on_trace_ready=profiler.tensorboard_trace_handler("./logs"),  # Optional logging
    record_shapes=True,
    with_stack=True
) as prof:
    with torch.no_grad():
        model(dummy_input)


# Print results
print(prof.key_averages().table(sort_by="cuda_time_total" if torch.cuda.is_available() else "cpu_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::conv2d         0.75%      37.576us        59.83%       3.012ms     502.063us       0.000us         0.00%     722.915us     120.486us             6
#                                       aten::convolution         2.46%     123.768us        59.09%       2.975ms     495.800us       0.000us         0.00%     722.915us     120.486us             6
#                                      aten::_convolution         1.68%      84.633us        56.63%       2.851ms     475.172us       0.000us         0.00%     722.915us     120.486us             6
#                                 aten::cudnn_convolution        47.75%       2.404ms        53.53%       2.695ms     449.183us     708.450us        61.60%     708.450us     118.075us             6
#        _5x_cudnn_ampere_scudnn_128x64_relu_medium_nn_v1         0.00%       0.000us         0.00%       0.000us       0.000us     308.640us        26.84%     308.640us     308.640us             1
#                                        aten::batch_norm         0.60%      30.115us        10.70%     538.787us     107.757us       0.000us         0.00%     200.894us      40.179us             5
#                            aten::_batch_norm_impl_index         0.76%      38.082us        10.10%     508.672us     101.734us       0.000us         0.00%     200.894us      40.179us             5
#                                  aten::cudnn_batch_norm         4.31%     217.035us         9.35%     470.590us      94.118us     200.894us        17.47%     200.894us      40.179us             5
# void cudnn::bn_fw_inf_1C11_kernel_NCHW<float, float,...         0.00%       0.000us         0.00%       0.000us       0.000us     200.894us        17.47%     200.894us      40.179us             5
# sm80_xmma_fprop_implicit_gemm_tf32f32_tf32f32_f32_nh...         0.00%       0.000us         0.00%       0.000us       0.000us     130.433us        11.34%     130.433us      43.478us             3
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 5.035ms
# Self CUDA time total: 1.150ms

# %%
save_path = "HoViT_TinyFusion_NCT-CRC-HE-100K.pth"
torch.save(model.state_dict(), save_path)
print(f"Model weights saved to {save_path}")
# Out:
# Model weights saved to HoViT_TinyFusion_NCT-CRC-HE-100K.pth

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, roc_curve, auc

def score_evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_preds = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    overall_f1 = f1_score(all_labels, all_preds, average="macro")
    overall_recall = recall_score(all_labels, all_preds, average="macro")
    overall_precision = precision_score(all_labels, all_preds, average="macro")

    f1_per_class = f1_score(all_labels, all_preds, average=None)
    recall_per_class = recall_score(all_labels, all_preds, average=None)
    precision_per_class = precision_score(all_labels, all_preds, average=None)
    class_labels = sorted(set(all_labels))

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

    print(f"Overall - F1: {overall_f1:.4f}, Recall: {overall_recall:.4f}, Precision: {overall_precision:.4f}")
    print("Per-Class Metrics:")
    for i, label in enumerate(class_labels):
        print(f"Class {label} - F1: {f1_per_class[i]:.4f}, Recall: {recall_per_class[i]:.4f}, Precision: {precision_per_class[i]:.4f}")

    return overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class

# %%
from sklearn.preprocessing import label_binarize

def roc_auc(model, data_loader, device, num_classes):

    y = ["F1", "Precision", "Recall"]

    model.eval()
    all_labels = []
    all_scores = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc="ROC AUC"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            all_labels.extend(labels.cpu().numpy())
            all_scores.extend(outputs.cpu().numpy())

    all_labels = label_binarize(all_labels, classes=list(range(num_classes)))
    print(f"Binarized all_labels shape: {all_labels.shape}")
    print(f"All_scores shape: {np.array(all_scores).shape}")

    fpr, tpr, _ = roc_curve(all_labels.ravel(), np.array(all_scores).ravel())
    roc_auc_value = auc(fpr, tpr)

    plt.figure(figsize=(9, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc_value:0.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.show()

    print(f"Overall ROC AUC: {roc_auc_value:.4f}")

    return fpr, tpr, roc_auc_value

# %%
overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class = score_evaluate(model, test_loader, criterion, device, phase="Test")
# Out:
# Test: 100%|██████████| 469/469 [00:07<00:00, 66.14it/s]
# Test Loss: 0.5315, Test Accuracy: 84.35%
# Overall - F1: 0.8443, Recall: 0.8402, Precision: 0.9046
# Per-Class Metrics:
# Class 0 - F1: 0.9800, Recall: 0.9744, Precision: 0.9857
# Class 1 - F1: 0.9781, Recall: 0.9981, Precision: 0.9588
# Class 2 - F1: 0.8865, Recall: 0.9317, Precision: 0.8455
# Class 3 - F1: 0.9922, Recall: 0.9879, Precision: 0.9965
# Class 4 - F1: 0.5970, Recall: 0.4258, Precision: 0.9982
# Class 5 - F1: 0.7950, Recall: 0.6867, Precision: 0.9438
# Class 6 - F1: 0.8740, Recall: 0.7833, Precision: 0.9885
# Class 7 - F1: 0.6309, Recall: 0.9879, Precision: 0.4635
# Class 8 - F1: 0.8648, Recall: 0.7862, Precision: 0.9607

# %%
x = ["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", 'STR', "TUM"]
y = ["F1", "Precision", "Recall"]

f1_score_list = []
precision_score_list = []
recall_score_list = []

for i, class_name in enumerate(x):
    f1_score_list.append(f1_per_class[i])
    precision_score_list.append(precision_per_class[i])
    recall_score_list.append(recall_per_class[i])

x.append("Overall")
f1_score_list.append(overall_f1)
precision_score_list.append(overall_precision)
recall_score_list.append(overall_recall)

score_list = [f1_score_list, precision_score_list, recall_score_list]
score_list = np.array(score_list)
plt.figure(figsize=(20, 12))
score_cm = plt.matshow(score_list, cmap=plt.cm.Blues, alpha=0.3)
plt.xticks(range(len(x)), x)
plt.yticks(range(len(y)), y)
for i in range(len(y)):
    for j in range(len(x)):
        # 행렬의 각각의 수치를 각 칸의 중앙에 넣어준다
        plt.text(x=j, y=i,
                     s="{:.2f}".format(score_list[i, j]),
                     va='center',
                     ha='center',
                     )

# %%
def visualize_pruned_blocks(model):

    for stage_name, stage in model.named_children():
        if isinstance(stage, PrunedLevitStage):
            mask_probs = stage.learnable_mask().detach().cpu().numpy()
            activated_blocks = np.sum(mask_probs > 0.5)
            total_blocks = len(mask_probs)

            print(f"🔥 {stage_name} -activation block number : {activated_blocks}/{total_blocks}")
            print(f"🔹 Block activation prob: {mask_probs}")

            plt.figure(figsize=(8, 1))
            plt.bar(range(total_blocks), mask_probs, color=['red' if p < 0.5 else 'blue' for p in mask_probs])
            plt.axhline(y=0.5, color='gray', linestyle='--')
            plt.xlabel("Block Index")
            plt.ylabel("Activation Probability")
            plt.title(f"{stage_name} Block Activation")

# %%
visualize_pruned_blocks(model)
# Out:
# 🔥 stage1 -activation block number : 0/6
# 🔹 Block activation prob: [0.44196618 0.20900574 0.1018361  0.05625048 0.02158777 0.16935372]
# 🔥 stage2 -activation block number : 0/6
# 🔹 Block activation prob: [0.32731003 0.03705598 0.16477227 0.32652327 0.00531275 0.13902573]
