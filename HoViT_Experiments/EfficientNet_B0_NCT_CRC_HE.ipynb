# %%
# !pip install wget torchinfo
# !wget -O NCT-CRC-HE-100K.zip https://zenodo.org/record/1214456/files/NCT-CRC-HE-100K.zip
# !unzip -qq NCT-CRC-HE-100K.zip -d train

# %%
# !wget -O CRC-VAL-HE-7K.zip https://zenodo.org/records/1214456/files/CRC-VAL-HE-7K.zip
# !unzip -qq CRC-VAL-HE-7K.zip -d test

# %%
# !pip install torchinfo

import cv2
import timm
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, ConcatDataset
import numpy as np
from tqdm import tqdm

import itertools
from torch import profiler
from torchinfo import summary

from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report, confusion_matrix
from PIL import Image

from matplotlib import pyplot as plt

import random
import torchvision.transforms.functional as TF

from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
model = timm.create_model('efficientnet_b0', pretrained=True)
print(model)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# EfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNormAct2d(
#     32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNormAct2d(
#           96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         (bn2): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#         (bn2): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (bn2): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (bn2): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#         (bn2): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#   )
#   (conv_head): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNormAct2d(
#     1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=1280, out_features=1000, bias=True)
# )

# %%
# PAPER HYPERPARM SETTING
batch_size = 32
learning_rate = 5e-4
decay_rate = 1e-6
num_epochs = 30

# %%
print(summary(model, input_size=(32, 3, 224, 224)))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# EfficientNet                                  [32, 1000]                --
# ├─Conv2d: 1-1                                 [32, 32, 112, 112]        864
# ├─BatchNormAct2d: 1-2                         [32, 32, 112, 112]        64
# │    └─Identity: 2-1                          [32, 32, 112, 112]        --
# │    └─SiLU: 2-2                              [32, 32, 112, 112]        --
# ├─Sequential: 1-3                             [32, 320, 7, 7]           --
# │    └─Sequential: 2-3                        [32, 16, 112, 112]        --
# │    │    └─DepthwiseSeparableConv: 3-1       [32, 16, 112, 112]        1,448
# │    └─Sequential: 2-4                        [32, 24, 56, 56]          --
# │    │    └─InvertedResidual: 3-2             [32, 24, 56, 56]          6,004
# │    │    └─InvertedResidual: 3-3             [32, 24, 56, 56]          10,710
# │    └─Sequential: 2-5                        [32, 40, 28, 28]          --
# │    │    └─InvertedResidual: 3-4             [32, 40, 28, 28]          15,350
# │    │    └─InvertedResidual: 3-5             [32, 40, 28, 28]          31,290
# │    └─Sequential: 2-6                        [32, 80, 14, 14]          --
# │    │    └─InvertedResidual: 3-6             [32, 80, 14, 14]          37,130
# │    │    └─InvertedResidual: 3-7             [32, 80, 14, 14]          102,900
# │    │    └─InvertedResidual: 3-8             [32, 80, 14, 14]          102,900
# │    └─Sequential: 2-7                        [32, 112, 14, 14]         --
# │    │    └─InvertedResidual: 3-9             [32, 112, 14, 14]         126,004
# │    │    └─InvertedResidual: 3-10            [32, 112, 14, 14]         208,572
# │    │    └─InvertedResidual: 3-11            [32, 112, 14, 14]         208,572
# │    └─Sequential: 2-8                        [32, 192, 7, 7]           --
# │    │    └─InvertedResidual: 3-12            [32, 192, 7, 7]           262,492
# │    │    └─InvertedResidual: 3-13            [32, 192, 7, 7]           587,952
# │    │    └─InvertedResidual: 3-14            [32, 192, 7, 7]           587,952
# │    │    └─InvertedResidual: 3-15            [32, 192, 7, 7]           587,952
# │    └─Sequential: 2-9                        [32, 320, 7, 7]           --
# │    │    └─InvertedResidual: 3-16            [32, 320, 7, 7]           717,232
# ├─Conv2d: 1-4                                 [32, 1280, 7, 7]          409,600
# ├─BatchNormAct2d: 1-5                         [32, 1280, 7, 7]          2,560
# │    └─Identity: 2-10                         [32, 1280, 7, 7]          --
# │    └─SiLU: 2-11                             [32, 1280, 7, 7]          --
# ├─SelectAdaptivePool2d: 1-6                   [32, 1280]                --
# │    └─AdaptiveAvgPool2d: 2-12                [32, 1280, 1, 1]          --
# │    └─Flatten: 2-13                          [32, 1280]                --
# ├─Linear: 1-7                                 [32, 1000]                1,281,000
# ===============================================================================================
# Total params: 5,288,548
# Trainable params: 5,288,548
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 12.35
# ===============================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 1727.50
# Params size (MB): 20.99
# Estimated Total Size (MB): 1767.75
# ===============================================================================================

# %%
print(summary(model, input_size=(32, 3, 224, 224), verbose=2))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# EfficientNet                                  [32, 1000]                --
# ├─Conv2d: 1-1                                 [32, 32, 112, 112]        864
# │    └─weight                                                           └─864
# ├─BatchNormAct2d: 1-2                         [32, 32, 112, 112]        64
# │    └─weight                                                           ├─32
# │    └─bias                                                             └─32
# │    └─Identity: 2-1                          [32, 32, 112, 112]        --
# │    └─SiLU: 2-2                              [32, 32, 112, 112]        --
# ├─Sequential: 1-3                             [32, 320, 7, 7]           --
# │    └─0.0.conv_dw.weight                                               ├─288
# │    └─0.0.bn1.weight                                                   ├─32
# │    └─0.0.bn1.bias                                                     ├─32
# │    └─0.0.se.conv_reduce.weight                                        ├─256
# │    └─0.0.se.conv_reduce.bias                                          ├─8
# │    └─0.0.se.conv_expand.weight                                        ├─256
# │    └─0.0.se.conv_expand.bias                                          ├─32
# │    └─0.0.conv_pw.weight                                               ├─512
# │    └─0.0.bn2.weight                                                   ├─16
# │    └─0.0.bn2.bias                                                     ├─16
# │    └─1.0.conv_pw.weight                                               ├─1,536
# │    └─1.0.bn1.weight                                                   ├─96
# │    └─1.0.bn1.bias                                                     ├─96
# │    └─1.0.conv_dw.weight                                               ├─864
# │    └─1.0.bn2.weight                                                   ├─96
# │    └─1.0.bn2.bias                                                     ├─96
# │    └─1.0.se.conv_reduce.weight                                        ├─384
# │    └─1.0.se.conv_reduce.bias                                          ├─4
# │    └─1.0.se.conv_expand.weight                                        ├─384
# │    └─1.0.se.conv_expand.bias                                          ├─96
# │    └─1.0.conv_pwl.weight                                              ├─2,304
# │    └─1.0.bn3.weight                                                   ├─24
# │    └─1.0.bn3.bias                                                     ├─24
# │    └─1.1.conv_pw.weight                                               ├─3,456
# │    └─1.1.bn1.weight                                                   ├─144
# │    └─1.1.bn1.bias                                                     ├─144
# │    └─1.1.conv_dw.weight                                               ├─1,296
# │    └─1.1.bn2.weight                                                   ├─144
# │    └─1.1.bn2.bias                                                     ├─144
# │    └─1.1.se.conv_reduce.weight                                        ├─864
# │    └─1.1.se.conv_reduce.bias                                          ├─6
# │    └─1.1.se.conv_expand.weight                                        ├─864
# │    └─1.1.se.conv_expand.bias                                          ├─144
# │    └─1.1.conv_pwl.weight                                              ├─3,456
# │    └─1.1.bn3.weight                                                   ├─24
# │    └─1.1.bn3.bias                                                     ├─24
# │    └─2.0.conv_pw.weight                                               ├─3,456
# │    └─2.0.bn1.weight                                                   ├─144
# │    └─2.0.bn1.bias                                                     ├─144
# │    └─2.0.conv_dw.weight                                               ├─3,600
# │    └─2.0.bn2.weight                                                   ├─144
# │    └─2.0.bn2.bias                                                     ├─144
# │    └─2.0.se.conv_reduce.weight                                        ├─864
# │    └─2.0.se.conv_reduce.bias                                          ├─6
# │    └─2.0.se.conv_expand.weight                                        ├─864
# │    └─2.0.se.conv_expand.bias                                          ├─144
# │    └─2.0.conv_pwl.weight                                              ├─5,760
# │    └─2.0.bn3.weight                                                   ├─40
# │    └─2.0.bn3.bias                                                     ├─40
# │    └─2.1.conv_pw.weight                                               ├─9,600
# │    └─2.1.bn1.weight                                                   ├─240
# │    └─2.1.bn1.bias                                                     ├─240
# │    └─2.1.conv_dw.weight                                               ├─6,000
# │    └─2.1.bn2.weight                                                   ├─240
# │    └─2.1.bn2.bias                                                     ├─240
# │    └─2.1.se.conv_reduce.weight                                        ├─2,400
# │    └─2.1.se.conv_reduce.bias                                          ├─10
# │    └─2.1.se.conv_expand.weight                                        ├─2,400
# │    └─2.1.se.conv_expand.bias                                          ├─240
# │    └─2.1.conv_pwl.weight                                              ├─9,600
# │    └─2.1.bn3.weight                                                   ├─40
# │    └─2.1.bn3.bias                                                     ├─40
# │    └─3.0.conv_pw.weight                                               ├─9,600
# │    └─3.0.bn1.weight                                                   ├─240
# │    └─3.0.bn1.bias                                                     ├─240
# │    └─3.0.conv_dw.weight                                               ├─2,160
# │    └─3.0.bn2.weight                                                   ├─240
# │    └─3.0.bn2.bias                                                     ├─240
# │    └─3.0.se.conv_reduce.weight                                        ├─2,400
# │    └─3.0.se.conv_reduce.bias                                          ├─10
# │    └─3.0.se.conv_expand.weight                                        ├─2,400
# │    └─3.0.se.conv_expand.bias                                          ├─240
# │    └─3.0.conv_pwl.weight                                              ├─19,200
# │    └─3.0.bn3.weight                                                   ├─80
# │    └─3.0.bn3.bias                                                     ├─80
# │    └─3.1.conv_pw.weight                                               ├─38,400
# │    └─3.1.bn1.weight                                                   ├─480
# │    └─3.1.bn1.bias                                                     ├─480
# │    └─3.1.conv_dw.weight                                               ├─4,320
# │    └─3.1.bn2.weight                                                   ├─480
# │    └─3.1.bn2.bias                                                     ├─480
# │    └─3.1.se.conv_reduce.weight                                        ├─9,600
# │    └─3.1.se.conv_reduce.bias                                          ├─20
# │    └─3.1.se.conv_expand.weight                                        ├─9,600
# │    └─3.1.se.conv_expand.bias                                          ├─480
# │    └─3.1.conv_pwl.weight                                              ├─38,400
# │    └─3.1.bn3.weight                                                   ├─80
# │    └─3.1.bn3.bias                                                     ├─80
# │    └─3.2.conv_pw.weight                                               ├─38,400
# │    └─3.2.bn1.weight                                                   ├─480
# │    └─3.2.bn1.bias                                                     ├─480
# │    └─3.2.conv_dw.weight                                               ├─4,320
# │    └─3.2.bn2.weight                                                   ├─480
# │    └─3.2.bn2.bias                                                     ├─480
# │    └─3.2.se.conv_reduce.weight                                        ├─9,600
# │    └─3.2.se.conv_reduce.bias                                          ├─20
# │    └─3.2.se.conv_expand.weight                                        ├─9,600
# │    └─3.2.se.conv_expand.bias                                          ├─480
# │    └─3.2.conv_pwl.weight                                              ├─38,400
# │    └─3.2.bn3.weight                                                   ├─80
# │    └─3.2.bn3.bias                                                     ├─80
# │    └─4.0.conv_pw.weight                                               ├─38,400
# │    └─4.0.bn1.weight                                                   ├─480
# │    └─4.0.bn1.bias                                                     ├─480
# │    └─4.0.conv_dw.weight                                               ├─12,000
# │    └─4.0.bn2.weight                                                   ├─480
# │    └─4.0.bn2.bias                                                     ├─480
# │    └─4.0.se.conv_reduce.weight                                        ├─9,600
# │    └─4.0.se.conv_reduce.bias                                          ├─20
# │    └─4.0.se.conv_expand.weight                                        ├─9,600
# │    └─4.0.se.conv_expand.bias                                          ├─480
# │    └─4.0.conv_pwl.weight                                              ├─53,760
# │    └─4.0.bn3.weight                                                   ├─112
# │    └─4.0.bn3.bias                                                     ├─112
# │    └─4.1.conv_pw.weight                                               ├─75,264
# │    └─4.1.bn1.weight                                                   ├─672
# │    └─4.1.bn1.bias                                                     ├─672
# │    └─4.1.conv_dw.weight                                               ├─16,800
# │    └─4.1.bn2.weight                                                   ├─672
# │    └─4.1.bn2.bias                                                     ├─672
# │    └─4.1.se.conv_reduce.weight                                        ├─18,816
# │    └─4.1.se.conv_reduce.bias                                          ├─28
# │    └─4.1.se.conv_expand.weight                                        ├─18,816
# │    └─4.1.se.conv_expand.bias                                          ├─672
# │    └─4.1.conv_pwl.weight                                              ├─75,264
# │    └─4.1.bn3.weight                                                   ├─112
# │    └─4.1.bn3.bias                                                     ├─112
# │    └─4.2.conv_pw.weight                                               ├─75,264
# │    └─4.2.bn1.weight                                                   ├─672
# │    └─4.2.bn1.bias                                                     ├─672
# │    └─4.2.conv_dw.weight                                               ├─16,800
# │    └─4.2.bn2.weight                                                   ├─672
# │    └─4.2.bn2.bias                                                     ├─672
# │    └─4.2.se.conv_reduce.weight                                        ├─18,816
# │    └─4.2.se.conv_reduce.bias                                          ├─28
# │    └─4.2.se.conv_expand.weight                                        ├─18,816
# │    └─4.2.se.conv_expand.bias                                          ├─672
# │    └─4.2.conv_pwl.weight                                              ├─75,264
# │    └─4.2.bn3.weight                                                   ├─112
# │    └─4.2.bn3.bias                                                     ├─112
# │    └─5.0.conv_pw.weight                                               ├─75,264
# │    └─5.0.bn1.weight                                                   ├─672
# │    └─5.0.bn1.bias                                                     ├─672
# │    └─5.0.conv_dw.weight                                               ├─16,800
# │    └─5.0.bn2.weight                                                   ├─672
# │    └─5.0.bn2.bias                                                     ├─672
# │    └─5.0.se.conv_reduce.weight                                        ├─18,816
# │    └─5.0.se.conv_reduce.bias                                          ├─28
# │    └─5.0.se.conv_expand.weight                                        ├─18,816
# │    └─5.0.se.conv_expand.bias                                          ├─672
# │    └─5.0.conv_pwl.weight                                              ├─129,024
# │    └─5.0.bn3.weight                                                   ├─192
# │    └─5.0.bn3.bias                                                     ├─192
# │    └─5.1.conv_pw.weight                                               ├─221,184
# │    └─5.1.bn1.weight                                                   ├─1,152
# │    └─5.1.bn1.bias                                                     ├─1,152
# │    └─5.1.conv_dw.weight                                               ├─28,800
# │    └─5.1.bn2.weight                                                   ├─1,152
# │    └─5.1.bn2.bias                                                     ├─1,152
# │    └─5.1.se.conv_reduce.weight                                        ├─55,296
# │    └─5.1.se.conv_reduce.bias                                          ├─48
# │    └─5.1.se.conv_expand.weight                                        ├─55,296
# │    └─5.1.se.conv_expand.bias                                          ├─1,152
# │    └─5.1.conv_pwl.weight                                              ├─221,184
# │    └─5.1.bn3.weight                                                   ├─192
# │    └─5.1.bn3.bias                                                     ├─192
# │    └─5.2.conv_pw.weight                                               ├─221,184
# │    └─5.2.bn1.weight                                                   ├─1,152
# │    └─5.2.bn1.bias                                                     ├─1,152
# │    └─5.2.conv_dw.weight                                               ├─28,800
# │    └─5.2.bn2.weight                                                   ├─1,152
# │    └─5.2.bn2.bias                                                     ├─1,152
# │    └─5.2.se.conv_reduce.weight                                        ├─55,296
# │    └─5.2.se.conv_reduce.bias                                          ├─48
# │    └─5.2.se.conv_expand.weight                                        ├─55,296
# │    └─5.2.se.conv_expand.bias                                          ├─1,152
# │    └─5.2.conv_pwl.weight                                              ├─221,184
# │    └─5.2.bn3.weight                                                   ├─192
# │    └─5.2.bn3.bias                                                     ├─192
# │    └─5.3.conv_pw.weight                                               ├─221,184
# │    └─5.3.bn1.weight                                                   ├─1,152
# │    └─5.3.bn1.bias                                                     ├─1,152
# │    └─5.3.conv_dw.weight                                               ├─28,800
# │    └─5.3.bn2.weight                                                   ├─1,152
# │    └─5.3.bn2.bias                                                     ├─1,152
# │    └─5.3.se.conv_reduce.weight                                        ├─55,296
# │    └─5.3.se.conv_reduce.bias                                          ├─48
# │    └─5.3.se.conv_expand.weight                                        ├─55,296
# │    └─5.3.se.conv_expand.bias                                          ├─1,152
# │    └─5.3.conv_pwl.weight                                              ├─221,184
# │    └─5.3.bn3.weight                                                   ├─192
# │    └─5.3.bn3.bias                                                     ├─192
# │    └─6.0.conv_pw.weight                                               ├─221,184
# │    └─6.0.bn1.weight                                                   ├─1,152
# │    └─6.0.bn1.bias                                                     ├─1,152
# │    └─6.0.conv_dw.weight                                               ├─10,368
# │    └─6.0.bn2.weight                                                   ├─1,152
# │    └─6.0.bn2.bias                                                     ├─1,152
# │    └─6.0.se.conv_reduce.weight                                        ├─55,296
# │    └─6.0.se.conv_reduce.bias                                          ├─48
# │    └─6.0.se.conv_expand.weight                                        ├─55,296
# │    └─6.0.se.conv_expand.bias                                          ├─1,152
# │    └─6.0.conv_pwl.weight                                              ├─368,640
# │    └─6.0.bn3.weight                                                   ├─320
# │    └─6.0.bn3.bias                                                     └─320
# │    └─Sequential: 2-3                        [32, 16, 112, 112]        --
# │    │    └─0.conv_dw.weight                                            ├─288
# │    │    └─0.bn1.weight                                                ├─32
# │    │    └─0.bn1.bias                                                  ├─32
# │    │    └─0.se.conv_reduce.weight                                     ├─256
# │    │    └─0.se.conv_reduce.bias                                       ├─8
# │    │    └─0.se.conv_expand.weight                                     ├─256
# │    │    └─0.se.conv_expand.bias                                       ├─32
# │    │    └─0.conv_pw.weight                                            ├─512
# │    │    └─0.bn2.weight                                                ├─16
# │    │    └─0.bn2.bias                                                  └─16
# │    │    └─DepthwiseSeparableConv: 3-1       [32, 16, 112, 112]        1,448
# │    │    │    └─conv_dw.weight                                         ├─288
# │    │    │    └─bn1.weight                                             ├─32
# │    │    │    └─bn1.bias                                               ├─32
# │    │    │    └─se.conv_reduce.weight                                  ├─256
# │    │    │    └─se.conv_reduce.bias                                    ├─8
# │    │    │    └─se.conv_expand.weight                                  ├─256
# │    │    │    └─se.conv_expand.bias                                    ├─32
# │    │    │    └─conv_pw.weight                                         ├─512
# │    │    │    └─bn2.weight                                             ├─16
# │    │    │    └─bn2.bias                                               └─16
# │    └─Sequential: 2-4                        [32, 24, 56, 56]          --
# │    │    └─0.conv_pw.weight                                            ├─1,536
# │    │    └─0.bn1.weight                                                ├─96
# │    │    └─0.bn1.bias                                                  ├─96
# │    │    └─0.conv_dw.weight                                            ├─864
# │    │    └─0.bn2.weight                                                ├─96
# │    │    └─0.bn2.bias                                                  ├─96
# │    │    └─0.se.conv_reduce.weight                                     ├─384
# │    │    └─0.se.conv_reduce.bias                                       ├─4
# │    │    └─0.se.conv_expand.weight                                     ├─384
# │    │    └─0.se.conv_expand.bias                                       ├─96
# │    │    └─0.conv_pwl.weight                                           ├─2,304
# │    │    └─0.bn3.weight                                                ├─24
# │    │    └─0.bn3.bias                                                  ├─24
# │    │    └─1.conv_pw.weight                                            ├─3,456
# │    │    └─1.bn1.weight                                                ├─144
# │    │    └─1.bn1.bias                                                  ├─144
# │    │    └─1.conv_dw.weight                                            ├─1,296
# │    │    └─1.bn2.weight                                                ├─144
# │    │    └─1.bn2.bias                                                  ├─144
# │    │    └─1.se.conv_reduce.weight                                     ├─864
# │    │    └─1.se.conv_reduce.bias                                       ├─6
# │    │    └─1.se.conv_expand.weight                                     ├─864
# │    │    └─1.se.conv_expand.bias                                       ├─144
# │    │    └─1.conv_pwl.weight                                           ├─3,456
# │    │    └─1.bn3.weight                                                ├─24
# │    │    └─1.bn3.bias                                                  └─24
# │    │    └─InvertedResidual: 3-2             [32, 24, 56, 56]          6,004
# │    │    │    └─conv_pw.weight                                         ├─1,536
# │    │    │    └─bn1.weight                                             ├─96
# │    │    │    └─bn1.bias                                               ├─96
# │    │    │    └─conv_dw.weight                                         ├─864
# │    │    │    └─bn2.weight                                             ├─96
# │    │    │    └─bn2.bias                                               ├─96
# │    │    │    └─se.conv_reduce.weight                                  ├─384
# │    │    │    └─se.conv_reduce.bias                                    ├─4
# │    │    │    └─se.conv_expand.weight                                  ├─384
# │    │    │    └─se.conv_expand.bias                                    ├─96
# │    │    │    └─conv_pwl.weight                                        ├─2,304
# │    │    │    └─bn3.weight                                             ├─24
# │    │    │    └─bn3.bias                                               └─24
# │    │    └─InvertedResidual: 3-3             [32, 24, 56, 56]          10,710
# │    │    │    └─conv_pw.weight                                         ├─3,456
# │    │    │    └─bn1.weight                                             ├─144
# │    │    │    └─bn1.bias                                               ├─144
# │    │    │    └─conv_dw.weight                                         ├─1,296
# │    │    │    └─bn2.weight                                             ├─144
# │    │    │    └─bn2.bias                                               ├─144
# │    │    │    └─se.conv_reduce.weight                                  ├─864
# │    │    │    └─se.conv_reduce.bias                                    ├─6
# │    │    │    └─se.conv_expand.weight                                  ├─864
# │    │    │    └─se.conv_expand.bias                                    ├─144
# │    │    │    └─conv_pwl.weight                                        ├─3,456
# │    │    │    └─bn3.weight                                             ├─24
# │    │    │    └─bn3.bias                                               └─24
# │    └─Sequential: 2-5                        [32, 40, 28, 28]          --
# │    │    └─0.conv_pw.weight                                            ├─3,456
# │    │    └─0.bn1.weight                                                ├─144
# │    │    └─0.bn1.bias                                                  ├─144
# │    │    └─0.conv_dw.weight                                            ├─3,600
# │    │    └─0.bn2.weight                                                ├─144
# │    │    └─0.bn2.bias                                                  ├─144
# │    │    └─0.se.conv_reduce.weight                                     ├─864
# │    │    └─0.se.conv_reduce.bias                                       ├─6
# │    │    └─0.se.conv_expand.weight                                     ├─864
# │    │    └─0.se.conv_expand.bias                                       ├─144
# │    │    └─0.conv_pwl.weight                                           ├─5,760
# │    │    └─0.bn3.weight                                                ├─40
# │    │    └─0.bn3.bias                                                  ├─40
# │    │    └─1.conv_pw.weight                                            ├─9,600
# │    │    └─1.bn1.weight                                                ├─240
# │    │    └─1.bn1.bias                                                  ├─240
# │    │    └─1.conv_dw.weight                                            ├─6,000
# │    │    └─1.bn2.weight                                                ├─240
# │    │    └─1.bn2.bias                                                  ├─240
# │    │    └─1.se.conv_reduce.weight                                     ├─2,400
# │    │    └─1.se.conv_reduce.bias                                       ├─10
# │    │    └─1.se.conv_expand.weight                                     ├─2,400
# │    │    └─1.se.conv_expand.bias                                       ├─240
# │    │    └─1.conv_pwl.weight                                           ├─9,600
# │    │    └─1.bn3.weight                                                ├─40
# │    │    └─1.bn3.bias                                                  └─40
# │    │    └─InvertedResidual: 3-4             [32, 40, 28, 28]          15,350
# │    │    │    └─conv_pw.weight                                         ├─3,456
# │    │    │    └─bn1.weight                                             ├─144
# │    │    │    └─bn1.bias                                               ├─144
# │    │    │    └─conv_dw.weight                                         ├─3,600
# │    │    │    └─bn2.weight                                             ├─144
# │    │    │    └─bn2.bias                                               ├─144
# │    │    │    └─se.conv_reduce.weight                                  ├─864
# │    │    │    └─se.conv_reduce.bias                                    ├─6
# │    │    │    └─se.conv_expand.weight                                  ├─864
# │    │    │    └─se.conv_expand.bias                                    ├─144
# │    │    │    └─conv_pwl.weight                                        ├─5,760
# │    │    │    └─bn3.weight                                             ├─40
# │    │    │    └─bn3.bias                                               └─40
# │    │    └─InvertedResidual: 3-5             [32, 40, 28, 28]          31,290
# │    │    │    └─conv_pw.weight                                         ├─9,600
# │    │    │    └─bn1.weight                                             ├─240
# │    │    │    └─bn1.bias                                               ├─240
# │    │    │    └─conv_dw.weight                                         ├─6,000
# │    │    │    └─bn2.weight                                             ├─240
# │    │    │    └─bn2.bias                                               ├─240
# │    │    │    └─se.conv_reduce.weight                                  ├─2,400
# │    │    │    └─se.conv_reduce.bias                                    ├─10
# │    │    │    └─se.conv_expand.weight                                  ├─2,400
# │    │    │    └─se.conv_expand.bias                                    ├─240
# │    │    │    └─conv_pwl.weight                                        ├─9,600
# │    │    │    └─bn3.weight                                             ├─40
# │    │    │    └─bn3.bias                                               └─40
# │    └─Sequential: 2-6                        [32, 80, 14, 14]          --
# │    │    └─0.conv_pw.weight                                            ├─9,600
# │    │    └─0.bn1.weight                                                ├─240
# │    │    └─0.bn1.bias                                                  ├─240
# │    │    └─0.conv_dw.weight                                            ├─2,160
# │    │    └─0.bn2.weight                                                ├─240
# │    │    └─0.bn2.bias                                                  ├─240
# │    │    └─0.se.conv_reduce.weight                                     ├─2,400
# │    │    └─0.se.conv_reduce.bias                                       ├─10
# │    │    └─0.se.conv_expand.weight                                     ├─2,400
# │    │    └─0.se.conv_expand.bias                                       ├─240
# │    │    └─0.conv_pwl.weight                                           ├─19,200
# │    │    └─0.bn3.weight                                                ├─80
# │    │    └─0.bn3.bias                                                  ├─80
# │    │    └─1.conv_pw.weight                                            ├─38,400
# │    │    └─1.bn1.weight                                                ├─480
# │    │    └─1.bn1.bias                                                  ├─480
# │    │    └─1.conv_dw.weight                                            ├─4,320
# │    │    └─1.bn2.weight                                                ├─480
# │    │    └─1.bn2.bias                                                  ├─480
# │    │    └─1.se.conv_reduce.weight                                     ├─9,600
# │    │    └─1.se.conv_reduce.bias                                       ├─20
# │    │    └─1.se.conv_expand.weight                                     ├─9,600
# │    │    └─1.se.conv_expand.bias                                       ├─480
# │    │    └─1.conv_pwl.weight                                           ├─38,400
# │    │    └─1.bn3.weight                                                ├─80
# │    │    └─1.bn3.bias                                                  ├─80
# │    │    └─2.conv_pw.weight                                            ├─38,400
# │    │    └─2.bn1.weight                                                ├─480
# │    │    └─2.bn1.bias                                                  ├─480
# │    │    └─2.conv_dw.weight                                            ├─4,320
# │    │    └─2.bn2.weight                                                ├─480
# │    │    └─2.bn2.bias                                                  ├─480
# │    │    └─2.se.conv_reduce.weight                                     ├─9,600
# │    │    └─2.se.conv_reduce.bias                                       ├─20
# │    │    └─2.se.conv_expand.weight                                     ├─9,600
# │    │    └─2.se.conv_expand.bias                                       ├─480
# │    │    └─2.conv_pwl.weight                                           ├─38,400
# │    │    └─2.bn3.weight                                                ├─80
# │    │    └─2.bn3.bias                                                  └─80
# │    │    └─InvertedResidual: 3-6             [32, 80, 14, 14]          37,130
# │    │    │    └─conv_pw.weight                                         ├─9,600
# │    │    │    └─bn1.weight                                             ├─240
# │    │    │    └─bn1.bias                                               ├─240
# │    │    │    └─conv_dw.weight                                         ├─2,160
# │    │    │    └─bn2.weight                                             ├─240
# │    │    │    └─bn2.bias                                               ├─240
# │    │    │    └─se.conv_reduce.weight                                  ├─2,400
# │    │    │    └─se.conv_reduce.bias                                    ├─10
# │    │    │    └─se.conv_expand.weight                                  ├─2,400
# │    │    │    └─se.conv_expand.bias                                    ├─240
# │    │    │    └─conv_pwl.weight                                        ├─19,200
# │    │    │    └─bn3.weight                                             ├─80
# │    │    │    └─bn3.bias                                               └─80
# │    │    └─InvertedResidual: 3-7             [32, 80, 14, 14]          102,900
# │    │    │    └─conv_pw.weight                                         ├─38,400
# │    │    │    └─bn1.weight                                             ├─480
# │    │    │    └─bn1.bias                                               ├─480
# │    │    │    └─conv_dw.weight                                         ├─4,320
# │    │    │    └─bn2.weight                                             ├─480
# │    │    │    └─bn2.bias                                               ├─480
# │    │    │    └─se.conv_reduce.weight                                  ├─9,600
# │    │    │    └─se.conv_reduce.bias                                    ├─20
# │    │    │    └─se.conv_expand.weight                                  ├─9,600
# │    │    │    └─se.conv_expand.bias                                    ├─480
# │    │    │    └─conv_pwl.weight                                        ├─38,400
# │    │    │    └─bn3.weight                                             ├─80
# │    │    │    └─bn3.bias                                               └─80
# │    │    └─InvertedResidual: 3-8             [32, 80, 14, 14]          102,900
# │    │    │    └─conv_pw.weight                                         ├─38,400
# │    │    │    └─bn1.weight                                             ├─480
# │    │    │    └─bn1.bias                                               ├─480
# │    │    │    └─conv_dw.weight                                         ├─4,320
# │    │    │    └─bn2.weight                                             ├─480
# │    │    │    └─bn2.bias                                               ├─480
# │    │    │    └─se.conv_reduce.weight                                  ├─9,600
# │    │    │    └─se.conv_reduce.bias                                    ├─20
# │    │    │    └─se.conv_expand.weight                                  ├─9,600
# │    │    │    └─se.conv_expand.bias                                    ├─480
# │    │    │    └─conv_pwl.weight                                        ├─38,400
# │    │    │    └─bn3.weight                                             ├─80
# │    │    │    └─bn3.bias                                               └─80
# │    └─Sequential: 2-7                        [32, 112, 14, 14]         --
# │    │    └─0.conv_pw.weight                                            ├─38,400
# │    │    └─0.bn1.weight                                                ├─480
# │    │    └─0.bn1.bias                                                  ├─480
# │    │    └─0.conv_dw.weight                                            ├─12,000
# │    │    └─0.bn2.weight                                                ├─480
# │    │    └─0.bn2.bias                                                  ├─480
# │    │    └─0.se.conv_reduce.weight                                     ├─9,600
# │    │    └─0.se.conv_reduce.bias                                       ├─20
# │    │    └─0.se.conv_expand.weight                                     ├─9,600
# │    │    └─0.se.conv_expand.bias                                       ├─480
# │    │    └─0.conv_pwl.weight                                           ├─53,760
# │    │    └─0.bn3.weight                                                ├─112
# │    │    └─0.bn3.bias                                                  ├─112
# │    │    └─1.conv_pw.weight                                            ├─75,264
# │    │    └─1.bn1.weight                                                ├─672
# │    │    └─1.bn1.bias                                                  ├─672
# │    │    └─1.conv_dw.weight                                            ├─16,800
# │    │    └─1.bn2.weight                                                ├─672
# │    │    └─1.bn2.bias                                                  ├─672
# │    │    └─1.se.conv_reduce.weight                                     ├─18,816
# │    │    └─1.se.conv_reduce.bias                                       ├─28
# │    │    └─1.se.conv_expand.weight                                     ├─18,816
# │    │    └─1.se.conv_expand.bias                                       ├─672
# │    │    └─1.conv_pwl.weight                                           ├─75,264
# │    │    └─1.bn3.weight                                                ├─112
# │    │    └─1.bn3.bias                                                  ├─112
# │    │    └─2.conv_pw.weight                                            ├─75,264
# │    │    └─2.bn1.weight                                                ├─672
# │    │    └─2.bn1.bias                                                  ├─672
# │    │    └─2.conv_dw.weight                                            ├─16,800
# │    │    └─2.bn2.weight                                                ├─672
# │    │    └─2.bn2.bias                                                  ├─672
# │    │    └─2.se.conv_reduce.weight                                     ├─18,816
# │    │    └─2.se.conv_reduce.bias                                       ├─28
# │    │    └─2.se.conv_expand.weight                                     ├─18,816
# │    │    └─2.se.conv_expand.bias                                       ├─672
# │    │    └─2.conv_pwl.weight                                           ├─75,264
# │    │    └─2.bn3.weight                                                ├─112
# │    │    └─2.bn3.bias                                                  └─112
# │    │    └─InvertedResidual: 3-9             [32, 112, 14, 14]         126,004
# │    │    │    └─conv_pw.weight                                         ├─38,400
# │    │    │    └─bn1.weight                                             ├─480
# │    │    │    └─bn1.bias                                               ├─480
# │    │    │    └─conv_dw.weight                                         ├─12,000
# │    │    │    └─bn2.weight                                             ├─480
# │    │    │    └─bn2.bias                                               ├─480
# │    │    │    └─se.conv_reduce.weight                                  ├─9,600
# │    │    │    └─se.conv_reduce.bias                                    ├─20
# │    │    │    └─se.conv_expand.weight                                  ├─9,600
# │    │    │    └─se.conv_expand.bias                                    ├─480
# │    │    │    └─conv_pwl.weight                                        ├─53,760
# │    │    │    └─bn3.weight                                             ├─112
# │    │    │    └─bn3.bias                                               └─112
# │    │    └─InvertedResidual: 3-10            [32, 112, 14, 14]         208,572
# │    │    │    └─conv_pw.weight                                         ├─75,264
# │    │    │    └─bn1.weight                                             ├─672
# │    │    │    └─bn1.bias                                               ├─672
# │    │    │    └─conv_dw.weight                                         ├─16,800
# │    │    │    └─bn2.weight                                             ├─672
# │    │    │    └─bn2.bias                                               ├─672
# │    │    │    └─se.conv_reduce.weight                                  ├─18,816
# │    │    │    └─se.conv_reduce.bias                                    ├─28
# │    │    │    └─se.conv_expand.weight                                  ├─18,816
# │    │    │    └─se.conv_expand.bias                                    ├─672
# │    │    │    └─conv_pwl.weight                                        ├─75,264
# │    │    │    └─bn3.weight                                             ├─112
# │    │    │    └─bn3.bias                                               └─112
# │    │    └─InvertedResidual: 3-11            [32, 112, 14, 14]         208,572
# │    │    │    └─conv_pw.weight                                         ├─75,264
# │    │    │    └─bn1.weight                                             ├─672
# │    │    │    └─bn1.bias                                               ├─672
# │    │    │    └─conv_dw.weight                                         ├─16,800
# │    │    │    └─bn2.weight                                             ├─672
# │    │    │    └─bn2.bias                                               ├─672
# │    │    │    └─se.conv_reduce.weight                                  ├─18,816
# │    │    │    └─se.conv_reduce.bias                                    ├─28
# │    │    │    └─se.conv_expand.weight                                  ├─18,816
# │    │    │    └─se.conv_expand.bias                                    ├─672
# │    │    │    └─conv_pwl.weight                                        ├─75,264
# │    │    │    └─bn3.weight                                             ├─112
# │    │    │    └─bn3.bias                                               └─112
# │    └─Sequential: 2-8                        [32, 192, 7, 7]           --
# │    │    └─0.conv_pw.weight                                            ├─75,264
# │    │    └─0.bn1.weight                                                ├─672
# │    │    └─0.bn1.bias                                                  ├─672
# │    │    └─0.conv_dw.weight                                            ├─16,800
# │    │    └─0.bn2.weight                                                ├─672
# │    │    └─0.bn2.bias                                                  ├─672
# │    │    └─0.se.conv_reduce.weight                                     ├─18,816
# │    │    └─0.se.conv_reduce.bias                                       ├─28
# │    │    └─0.se.conv_expand.weight                                     ├─18,816
# │    │    └─0.se.conv_expand.bias                                       ├─672
# │    │    └─0.conv_pwl.weight                                           ├─129,024
# │    │    └─0.bn3.weight                                                ├─192
# │    │    └─0.bn3.bias                                                  ├─192
# │    │    └─1.conv_pw.weight                                            ├─221,184
# │    │    └─1.bn1.weight                                                ├─1,152
# │    │    └─1.bn1.bias                                                  ├─1,152
# │    │    └─1.conv_dw.weight                                            ├─28,800
# │    │    └─1.bn2.weight                                                ├─1,152
# │    │    └─1.bn2.bias                                                  ├─1,152
# │    │    └─1.se.conv_reduce.weight                                     ├─55,296
# │    │    └─1.se.conv_reduce.bias                                       ├─48
# │    │    └─1.se.conv_expand.weight                                     ├─55,296
# │    │    └─1.se.conv_expand.bias                                       ├─1,152
# │    │    └─1.conv_pwl.weight                                           ├─221,184
# │    │    └─1.bn3.weight                                                ├─192
# │    │    └─1.bn3.bias                                                  ├─192
# │    │    └─2.conv_pw.weight                                            ├─221,184
# │    │    └─2.bn1.weight                                                ├─1,152
# │    │    └─2.bn1.bias                                                  ├─1,152
# │    │    └─2.conv_dw.weight                                            ├─28,800
# │    │    └─2.bn2.weight                                                ├─1,152
# │    │    └─2.bn2.bias                                                  ├─1,152
# │    │    └─2.se.conv_reduce.weight                                     ├─55,296
# │    │    └─2.se.conv_reduce.bias                                       ├─48
# │    │    └─2.se.conv_expand.weight                                     ├─55,296
# │    │    └─2.se.conv_expand.bias                                       ├─1,152
# │    │    └─2.conv_pwl.weight                                           ├─221,184
# │    │    └─2.bn3.weight                                                ├─192
# │    │    └─2.bn3.bias                                                  ├─192
# │    │    └─3.conv_pw.weight                                            ├─221,184
# │    │    └─3.bn1.weight                                                ├─1,152
# │    │    └─3.bn1.bias                                                  ├─1,152
# │    │    └─3.conv_dw.weight                                            ├─28,800
# │    │    └─3.bn2.weight                                                ├─1,152
# │    │    └─3.bn2.bias                                                  ├─1,152
# │    │    └─3.se.conv_reduce.weight                                     ├─55,296
# │    │    └─3.se.conv_reduce.bias                                       ├─48
# │    │    └─3.se.conv_expand.weight                                     ├─55,296
# │    │    └─3.se.conv_expand.bias                                       ├─1,152
# │    │    └─3.conv_pwl.weight                                           ├─221,184
# │    │    └─3.bn3.weight                                                ├─192
# │    │    └─3.bn3.bias                                                  └─192
# │    │    └─InvertedResidual: 3-12            [32, 192, 7, 7]           262,492
# │    │    │    └─conv_pw.weight                                         ├─75,264
# │    │    │    └─bn1.weight                                             ├─672
# │    │    │    └─bn1.bias                                               ├─672
# │    │    │    └─conv_dw.weight                                         ├─16,800
# │    │    │    └─bn2.weight                                             ├─672
# │    │    │    └─bn2.bias                                               ├─672
# │    │    │    └─se.conv_reduce.weight                                  ├─18,816
# │    │    │    └─se.conv_reduce.bias                                    ├─28
# │    │    │    └─se.conv_expand.weight                                  ├─18,816
# │    │    │    └─se.conv_expand.bias                                    ├─672
# │    │    │    └─conv_pwl.weight                                        ├─129,024
# │    │    │    └─bn3.weight                                             ├─192
# │    │    │    └─bn3.bias                                               └─192
# │    │    └─InvertedResidual: 3-13            [32, 192, 7, 7]           587,952
# │    │    │    └─conv_pw.weight                                         ├─221,184
# │    │    │    └─bn1.weight                                             ├─1,152
# │    │    │    └─bn1.bias                                               ├─1,152
# │    │    │    └─conv_dw.weight                                         ├─28,800
# │    │    │    └─bn2.weight                                             ├─1,152
# │    │    │    └─bn2.bias                                               ├─1,152
# │    │    │    └─se.conv_reduce.weight                                  ├─55,296
# │    │    │    └─se.conv_reduce.bias                                    ├─48
# │    │    │    └─se.conv_expand.weight                                  ├─55,296
# │    │    │    └─se.conv_expand.bias                                    ├─1,152
# │    │    │    └─conv_pwl.weight                                        ├─221,184
# │    │    │    └─bn3.weight                                             ├─192
# │    │    │    └─bn3.bias                                               └─192
# │    │    └─InvertedResidual: 3-14            [32, 192, 7, 7]           587,952
# │    │    │    └─conv_pw.weight                                         ├─221,184
# │    │    │    └─bn1.weight                                             ├─1,152
# │    │    │    └─bn1.bias                                               ├─1,152
# │    │    │    └─conv_dw.weight                                         ├─28,800
# │    │    │    └─bn2.weight                                             ├─1,152
# │    │    │    └─bn2.bias                                               ├─1,152
# │    │    │    └─se.conv_reduce.weight                                  ├─55,296
# │    │    │    └─se.conv_reduce.bias                                    ├─48
# │    │    │    └─se.conv_expand.weight                                  ├─55,296
# │    │    │    └─se.conv_expand.bias                                    ├─1,152
# │    │    │    └─conv_pwl.weight                                        ├─221,184
# │    │    │    └─bn3.weight                                             ├─192
# │    │    │    └─bn3.bias                                               └─192
# │    │    └─InvertedResidual: 3-15            [32, 192, 7, 7]           587,952
# ...
# │    │    └─2.bn3.weight                                                ├─112
# │    │    └─2.bn3.bias                                                  └─112
# │    │    └─InvertedResidual: 3-9             [32, 112, 14, 14]         126,004
# │    │    │    └─conv_pw.weight                                         ├─38,400
# │    │    │    └─bn1.weight                                             ├─480
# │    │    │    └─bn1.bias                                               ├─480
# │    │    │    └─conv_dw.weight                                         ├─12,000
# │    │    │    └─bn2.weight                                             ├─480
# │    │    │    └─bn2.bias                                               ├─480
# │    │    │    └─se.conv_reduce.weight                                  ├─9,600
# │    │    │    └─se.conv_reduce.bias                                    ├─20
# │    │    │    └─se.conv_expand.weight                                  ├─9,600
# │    │    │    └─se.conv_expand.bias                                    ├─480
# │    │    │    └─conv_pwl.weight                                        ├─53,760
# │    │    │    └─bn3.weight                                             ├─112
# │    │    │    └─bn3.bias                                               └─112
# │    │    └─InvertedResidual: 3-10            [32, 112, 14, 14]         208,572
# │    │    │    └─conv_pw.weight                                         ├─75,264
# │    │    │    └─bn1.weight                                             ├─672
# │    │    │    └─bn1.bias                                               ├─672
# │    │    │    └─conv_dw.weight                                         ├─16,800
# │    │    │    └─bn2.weight                                             ├─672
# │    │    │    └─bn2.bias                                               ├─672
# │    │    │    └─se.conv_reduce.weight                                  ├─18,816
# │    │    │    └─se.conv_reduce.bias                                    ├─28
# │    │    │    └─se.conv_expand.weight                                  ├─18,816
# │    │    │    └─se.conv_expand.bias                                    ├─672
# │    │    │    └─conv_pwl.weight                                        ├─75,264
# │    │    │    └─bn3.weight                                             ├─112
# │    │    │    └─bn3.bias                                               └─112
# │    │    └─InvertedResidual: 3-11            [32, 112, 14, 14]         208,572
# │    │    │    └─conv_pw.weight                                         ├─75,264
# │    │    │    └─bn1.weight                                             ├─672
# │    │    │    └─bn1.bias                                               ├─672
# │    │    │    └─conv_dw.weight                                         ├─16,800
# │    │    │    └─bn2.weight                                             ├─672
# │    │    │    └─bn2.bias                                               ├─672
# │    │    │    └─se.conv_reduce.weight                                  ├─18,816
# │    │    │    └─se.conv_reduce.bias                                    ├─28
# │    │    │    └─se.conv_expand.weight                                  ├─18,816
# │    │    │    └─se.conv_expand.bias                                    ├─672
# │    │    │    └─conv_pwl.weight                                        ├─75,264
# │    │    │    └─bn3.weight                                             ├─112
# │    │    │    └─bn3.bias                                               └─112
# │    └─Sequential: 2-8                        [32, 192, 7, 7]           --
# │    │    └─0.conv_pw.weight                                            ├─75,264
# │    │    └─0.bn1.weight                                                ├─672
# │    │    └─0.bn1.bias                                                  ├─672
# │    │    └─0.conv_dw.weight                                            ├─16,800
# │    │    └─0.bn2.weight                                                ├─672
# │    │    └─0.bn2.bias                                                  ├─672
# │    │    └─0.se.conv_reduce.weight                                     ├─18,816
# │    │    └─0.se.conv_reduce.bias                                       ├─28
# │    │    └─0.se.conv_expand.weight                                     ├─18,816
# │    │    └─0.se.conv_expand.bias                                       ├─672
# │    │    └─0.conv_pwl.weight                                           ├─129,024
# │    │    └─0.bn3.weight                                                ├─192
# │    │    └─0.bn3.bias                                                  ├─192
# │    │    └─1.conv_pw.weight                                            ├─221,184
# │    │    └─1.bn1.weight                                                ├─1,152
# │    │    └─1.bn1.bias                                                  ├─1,152
# │    │    └─1.conv_dw.weight                                            ├─28,800
# │    │    └─1.bn2.weight                                                ├─1,152
# │    │    └─1.bn2.bias                                                  ├─1,152
# │    │    └─1.se.conv_reduce.weight                                     ├─55,296
# │    │    └─1.se.conv_reduce.bias                                       ├─48
# │    │    └─1.se.conv_expand.weight                                     ├─55,296
# │    │    └─1.se.conv_expand.bias                                       ├─1,152
# │    │    └─1.conv_pwl.weight                                           ├─221,184
# │    │    └─1.bn3.weight                                                ├─192
# │    │    └─1.bn3.bias                                                  ├─192
# │    │    └─2.conv_pw.weight                                            ├─221,184
# │    │    └─2.bn1.weight                                                ├─1,152
# │    │    └─2.bn1.bias                                                  ├─1,152
# │    │    └─2.conv_dw.weight                                            ├─28,800
# │    │    └─2.bn2.weight                                                ├─1,152
# │    │    └─2.bn2.bias                                                  ├─1,152
# │    │    └─2.se.conv_reduce.weight                                     ├─55,296
# │    │    └─2.se.conv_reduce.bias                                       ├─48
# │    │    └─2.se.conv_expand.weight                                     ├─55,296
# │    │    └─2.se.conv_expand.bias                                       ├─1,152
# │    │    └─2.conv_pwl.weight                                           ├─221,184
# │    │    └─2.bn3.weight                                                ├─192
# │    │    └─2.bn3.bias                                                  ├─192
# │    │    └─3.conv_pw.weight                                            ├─221,184
# │    │    └─3.bn1.weight                                                ├─1,152
# │    │    └─3.bn1.bias                                                  ├─1,152
# │    │    └─3.conv_dw.weight                                            ├─28,800
# │    │    └─3.bn2.weight                                                ├─1,152
# │    │    └─3.bn2.bias                                                  ├─1,152
# │    │    └─3.se.conv_reduce.weight                                     ├─55,296
# │    │    └─3.se.conv_reduce.bias                                       ├─48
# │    │    └─3.se.conv_expand.weight                                     ├─55,296
# │    │    └─3.se.conv_expand.bias                                       ├─1,152
# │    │    └─3.conv_pwl.weight                                           ├─221,184
# │    │    └─3.bn3.weight                                                ├─192
# │    │    └─3.bn3.bias                                                  └─192
# │    │    └─InvertedResidual: 3-12            [32, 192, 7, 7]           262,492
# │    │    │    └─conv_pw.weight                                         ├─75,264
# │    │    │    └─bn1.weight                                             ├─672
# │    │    │    └─bn1.bias                                               ├─672
# │    │    │    └─conv_dw.weight                                         ├─16,800
# │    │    │    └─bn2.weight                                             ├─672
# │    │    │    └─bn2.bias                                               ├─672
# │    │    │    └─se.conv_reduce.weight                                  ├─18,816
# │    │    │    └─se.conv_reduce.bias                                    ├─28
# │    │    │    └─se.conv_expand.weight                                  ├─18,816
# │    │    │    └─se.conv_expand.bias                                    ├─672
# │    │    │    └─conv_pwl.weight                                        ├─129,024
# │    │    │    └─bn3.weight                                             ├─192
# │    │    │    └─bn3.bias                                               └─192
# │    │    └─InvertedResidual: 3-13            [32, 192, 7, 7]           587,952
# │    │    │    └─conv_pw.weight                                         ├─221,184
# │    │    │    └─bn1.weight                                             ├─1,152
# │    │    │    └─bn1.bias                                               ├─1,152
# │    │    │    └─conv_dw.weight                                         ├─28,800
# │    │    │    └─bn2.weight                                             ├─1,152
# │    │    │    └─bn2.bias                                               ├─1,152
# │    │    │    └─se.conv_reduce.weight                                  ├─55,296
# │    │    │    └─se.conv_reduce.bias                                    ├─48
# │    │    │    └─se.conv_expand.weight                                  ├─55,296
# │    │    │    └─se.conv_expand.bias                                    ├─1,152
# │    │    │    └─conv_pwl.weight                                        ├─221,184
# │    │    │    └─bn3.weight                                             ├─192
# │    │    │    └─bn3.bias                                               └─192
# │    │    └─InvertedResidual: 3-14            [32, 192, 7, 7]           587,952
# │    │    │    └─conv_pw.weight                                         ├─221,184
# │    │    │    └─bn1.weight                                             ├─1,152
# │    │    │    └─bn1.bias                                               ├─1,152
# │    │    │    └─conv_dw.weight                                         ├─28,800
# │    │    │    └─bn2.weight                                             ├─1,152
# │    │    │    └─bn2.bias                                               ├─1,152
# │    │    │    └─se.conv_reduce.weight                                  ├─55,296
# │    │    │    └─se.conv_reduce.bias                                    ├─48
# │    │    │    └─se.conv_expand.weight                                  ├─55,296
# │    │    │    └─se.conv_expand.bias                                    ├─1,152
# │    │    │    └─conv_pwl.weight                                        ├─221,184
# │    │    │    └─bn3.weight                                             ├─192
# │    │    │    └─bn3.bias                                               └─192
# │    │    └─InvertedResidual: 3-15            [32, 192, 7, 7]           587,952
# │    │    │    └─conv_pw.weight                                         ├─221,184
# │    │    │    └─bn1.weight                                             ├─1,152
# │    │    │    └─bn1.bias                                               ├─1,152
# │    │    │    └─conv_dw.weight                                         ├─28,800
# │    │    │    └─bn2.weight                                             ├─1,152
# │    │    │    └─bn2.bias                                               ├─1,152
# │    │    │    └─se.conv_reduce.weight                                  ├─55,296
# │    │    │    └─se.conv_reduce.bias                                    ├─48
# │    │    │    └─se.conv_expand.weight                                  ├─55,296
# │    │    │    └─se.conv_expand.bias                                    ├─1,152
# │    │    │    └─conv_pwl.weight                                        ├─221,184
# │    │    │    └─bn3.weight                                             ├─192
# │    │    │    └─bn3.bias                                               └─192
# │    └─Sequential: 2-9                        [32, 320, 7, 7]           --
# │    │    └─0.conv_pw.weight                                            ├─221,184
# │    │    └─0.bn1.weight                                                ├─1,152
# │    │    └─0.bn1.bias                                                  ├─1,152
# │    │    └─0.conv_dw.weight                                            ├─10,368
# │    │    └─0.bn2.weight                                                ├─1,152
# │    │    └─0.bn2.bias                                                  ├─1,152
# │    │    └─0.se.conv_reduce.weight                                     ├─55,296
# │    │    └─0.se.conv_reduce.bias                                       ├─48
# │    │    └─0.se.conv_expand.weight                                     ├─55,296
# │    │    └─0.se.conv_expand.bias                                       ├─1,152
# │    │    └─0.conv_pwl.weight                                           ├─368,640
# │    │    └─0.bn3.weight                                                ├─320
# │    │    └─0.bn3.bias                                                  └─320
# │    │    └─InvertedResidual: 3-16            [32, 320, 7, 7]           717,232
# │    │    │    └─conv_pw.weight                                         ├─221,184
# │    │    │    └─bn1.weight                                             ├─1,152
# │    │    │    └─bn1.bias                                               ├─1,152
# │    │    │    └─conv_dw.weight                                         ├─10,368
# │    │    │    └─bn2.weight                                             ├─1,152
# │    │    │    └─bn2.bias                                               ├─1,152
# │    │    │    └─se.conv_reduce.weight                                  ├─55,296
# │    │    │    └─se.conv_reduce.bias                                    ├─48
# │    │    │    └─se.conv_expand.weight                                  ├─55,296
# │    │    │    └─se.conv_expand.bias                                    ├─1,152
# │    │    │    └─conv_pwl.weight                                        ├─368,640
# │    │    │    └─bn3.weight                                             ├─320
# │    │    │    └─bn3.bias                                               └─320
# ├─Conv2d: 1-4                                 [32, 1280, 7, 7]          409,600
# │    └─weight                                                           └─409,600
# ├─BatchNormAct2d: 1-5                         [32, 1280, 7, 7]          2,560
# │    └─weight                                                           ├─1,280
# │    └─bias                                                             └─1,280
# │    └─Identity: 2-10                         [32, 1280, 7, 7]          --
# │    └─SiLU: 2-11                             [32, 1280, 7, 7]          --
# ├─SelectAdaptivePool2d: 1-6                   [32, 1280]                --
# │    └─AdaptiveAvgPool2d: 2-12                [32, 1280, 1, 1]          --
# │    └─Flatten: 2-13                          [32, 1280]                --
# ├─Linear: 1-7                                 [32, 1000]                1,281,000
# │    └─weight                                                           ├─1,280,000
# │    └─bias                                                             └─1,000
# ===============================================================================================
# Total params: 5,288,548
# Trainable params: 5,288,548
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 12.35
# ===============================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 1727.50
# Params size (MB): 20.99
# Estimated Total Size (MB): 1767.75
# ===============================================================================================

# %%
class DataAugmentation:
    def __init__(self, p_hflip=0.5, p_vflip=0.5, p_noise=0.2, p_blur=0.2, p_color=0.2, p_contrast=0.2):
        self.p_hflip = p_hflip
        self.p_vflip = p_vflip
        self.p_noise = p_noise
        self.p_blur = p_blur
        self.p_color = p_color
        self.p_contrast = p_contrast
    def __call__(self, img):
        if random.random() < self.p_hflip:
            img = TF.hflip(img)

        if random.random() < self.p_vflip:
            img = TF.vflip(img)

        if random.random() < self.p_noise:
            # img.size is a tuple, so unpack it as arguments for torch.randn
            noise = torch.randn(*img.size()) * 0.1  # Changed img.size() to img.size
            img = torch.clamp(img + noise, 0, 1)

        if random.random() < self.p_blur:
            img = TF.gaussian_blur(img, kernel_size=(5, 5), sigma=(0.1, 5))

        if random.random() < self.p_color:
            img = TF.adjust_saturation(img, saturation_factor = random.uniform(0.5, 1.5))

        if random.random() < self.p_contrast:
            img = TF.adjust_contrast(img, contrast_factor = random.uniform(0.5, 1.5))

        return img

# %%
# Updated transform with data augmentation
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    DataAugmentation(),
])

# %%
train_dir = './train/NCT-CRC-HE-100K'
dataset = datasets.ImageFolder(root=train_dir, transform=transform)

# %%
# Using StratifiedShuffleSplit from sklearn

data_paths, labels = zip(*dataset.samples)
labels = np.array(labels)

# 7 : 3 split
train_idx, tmp_idx, _, tmp_labels = train_test_split(
    np.arange(len(labels)), labels, test_size=0.3, stratify=labels, random_state=42
)

# 3 -> 1.5 : 1.5 split
val_idx, test_idx = train_test_split(
    tmp_idx, test_size=0.5, stratify=tmp_labels, random_state=42
)

train_data = Subset(dataset, train_idx)
val_data = Subset(dataset, val_idx)
test_data = Subset(dataset, test_idx)

# %%
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Train set size: 70000
# Validation set size: 15000
# Test set size: 15000

# %%
# Show one example per class from the training dataset
import matplotlib.pyplot as plt

# Prepare a dictionary to store one example per class
class_examples = {}
for images, labels in train_loader:
    for img, label in zip(images, labels):
        label = label.item()
        if label not in class_examples:
            class_examples[label] = img
        # Stop if we already have one example for each class
        if len(class_examples) == len(dataset.classes):
            break
    if len(class_examples) == len(dataset.classes):
        break

# Display the images and their labels
figure = plt.figure(figsize=(8, 8))
cols = 3  # You can adjust the number of columns as needed
rows = (len(dataset.classes) + cols - 1) // cols  # Calculate required rows
for i, (label, img) in enumerate(class_examples.items(), start=1):
    figure.add_subplot(rows, cols, i)
    plt.title(dataset.classes[label])
    plt.axis("off")
    plt.imshow(img.permute(1, 2, 0).numpy())  # Convert tensor to numpy for display
plt.show()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay = decay_rate)

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in tqdm(train_loader, desc="Training"):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {accuracy:.2f}%")
    train_losses.append(epoch_loss)
    train_accuracies.append(accuracy)

# %%
def evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

# %%
def measure_inference_time(model, data_loader, device):
    model.eval()
    times = []

    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            start_time = torch.cuda.Event(enable_timing=True)
            end_time = torch.cuda.Event(enable_timing=True)

            start_time.record()
            _ = model(inputs)  # inference 수행
            end_time.record()

            # 시간 측정
            torch.cuda.synchronize()  # CUDA에서 모든 커널이 완료될 때까지 대기
            elapsed_time = start_time.elapsed_time(end_time)  # 밀리초 단위로 반환
            times.append(elapsed_time)

    # 통계량 계산
    times_np = np.array(times)
    total_inferences = len(times_np)
    avg_time = np.mean(times_np)
    std_dev = np.std(times_np)
    max_time = np.max(times_np)
    min_time = np.min(times_np)

    # 결과 출력
    print(f"Inference Time Measurement Results:")
    print(f"Total Inferences: {total_inferences}")
    print(f"Average Time: {avg_time:.2f} ms")
    print(f"Standard Deviation: {std_dev:.2f} ms")
    print(f"Maximum Time: {max_time:.2f} ms")
    print(f"Minimum Time: {min_time:.2f} ms")

    return times

# %%
for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    train(model, train_loader, criterion, optimizer, device)
    evaluate(model, val_loader, criterion, device, phase="Validation")
# Out:
# Epoch 1/30
# Training: 100%|██████████| 2188/2188 [03:57<00:00,  9.21it/s]
# Train Loss: 0.1633, Train Accuracy: 95.33%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.74it/s]
# Validation Loss: 0.0560, Validation Accuracy: 98.23%
#
# Epoch 2/30
# Training: 100%|██████████| 2188/2188 [03:56<00:00,  9.26it/s]
# Train Loss: 0.0739, Train Accuracy: 97.64%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.68it/s]
# Validation Loss: 0.0484, Validation Accuracy: 98.47%
#
# Epoch 3/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.29it/s]
# Train Loss: 0.0574, Train Accuracy: 98.16%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.97it/s]
# Validation Loss: 0.0528, Validation Accuracy: 98.28%
#
# Epoch 4/30
# Training: 100%|██████████| 2188/2188 [03:54<00:00,  9.32it/s]
# Train Loss: 0.0498, Train Accuracy: 98.47%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 14.07it/s]
# Validation Loss: 0.0678, Validation Accuracy: 97.99%
#
# Epoch 5/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.28it/s]
# Train Loss: 0.0419, Train Accuracy: 98.64%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.99it/s]
# Validation Loss: 0.0370, Validation Accuracy: 98.79%
#
# Epoch 6/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.30it/s]
# Train Loss: 0.0380, Train Accuracy: 98.78%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 14.01it/s]
# Validation Loss: 0.0309, Validation Accuracy: 99.06%
#
# Epoch 7/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.28it/s]
# Train Loss: 0.0315, Train Accuracy: 98.98%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.75it/s]
# Validation Loss: 0.0249, Validation Accuracy: 99.15%
#
# Epoch 8/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.27it/s]
# Train Loss: 0.0307, Train Accuracy: 99.02%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.82it/s]
# Validation Loss: 0.0310, Validation Accuracy: 98.98%
#
# Epoch 9/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.27it/s]
# Train Loss: 0.0288, Train Accuracy: 99.09%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.82it/s]
# Validation Loss: 0.0221, Validation Accuracy: 99.24%
#
# Epoch 10/30
# Training: 100%|██████████| 2188/2188 [03:56<00:00,  9.26it/s]
# Train Loss: 0.0256, Train Accuracy: 99.17%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.69it/s]
# Validation Loss: 0.0276, Validation Accuracy: 99.09%
#
# Epoch 11/30
# Training: 100%|██████████| 2188/2188 [03:56<00:00,  9.26it/s]
# Train Loss: 0.0227, Train Accuracy: 99.28%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.91it/s]
# Validation Loss: 0.0244, Validation Accuracy: 99.31%
#
# Epoch 12/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.29it/s]
# Train Loss: 0.0222, Train Accuracy: 99.28%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.84it/s]
# Validation Loss: 0.0236, Validation Accuracy: 99.29%
#
# Epoch 13/30
# Training: 100%|██████████| 2188/2188 [03:56<00:00,  9.25it/s]
# Train Loss: 0.0224, Train Accuracy: 99.27%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 14.03it/s]
# Validation Loss: 0.0236, Validation Accuracy: 99.33%
#
# Epoch 14/30
# Training: 100%|██████████| 2188/2188 [03:56<00:00,  9.26it/s]
# Train Loss: 0.0206, Train Accuracy: 99.33%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.72it/s]
# Validation Loss: 0.0214, Validation Accuracy: 99.37%
#
# Epoch 15/30
# Training: 100%|██████████| 2188/2188 [03:55<00:00,  9.30it/s]
# Train Loss: 0.0203, Train Accuracy: 99.31%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.92it/s]
# Validation Loss: 0.0198, Validation Accuracy: 99.32%
#
# Epoch 16/30
# Training: 100%|██████████| 2188/2188 [03:59<00:00,  9.14it/s]
# Train Loss: 0.0179, Train Accuracy: 99.40%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.63it/s]
# Validation Loss: 0.0215, Validation Accuracy: 99.33%
#
# Epoch 17/30
# Training: 100%|██████████| 2188/2188 [03:59<00:00,  9.12it/s]
# Train Loss: 0.0161, Train Accuracy: 99.48%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.52it/s]
# Validation Loss: 0.0235, Validation Accuracy: 99.33%
#
# Epoch 18/30
# Training: 100%|██████████| 2188/2188 [03:59<00:00,  9.13it/s]
# Train Loss: 0.0178, Train Accuracy: 99.42%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.71it/s]
# Validation Loss: 0.0263, Validation Accuracy: 99.22%
#
# Epoch 19/30
# Training: 100%|██████████| 2188/2188 [03:57<00:00,  9.20it/s]
# Train Loss: 0.0143, Train Accuracy: 99.49%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.51it/s]
# Validation Loss: 0.0176, Validation Accuracy: 99.47%
#
# Epoch 20/30
# Training: 100%|██████████| 2188/2188 [03:59<00:00,  9.13it/s]
# Train Loss: 0.0186, Train Accuracy: 99.38%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.43it/s]
# Validation Loss: 0.0393, Validation Accuracy: 99.27%
#
# Epoch 21/30
# Training: 100%|██████████| 2188/2188 [04:00<00:00,  9.12it/s]
# Train Loss: 0.0153, Train Accuracy: 99.49%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.64it/s]
# Validation Loss: 0.0199, Validation Accuracy: 99.43%
#
# Epoch 22/30
# Training: 100%|██████████| 2188/2188 [04:00<00:00,  9.10it/s]
# Train Loss: 0.0149, Train Accuracy: 99.51%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.53it/s]
# Validation Loss: 0.0276, Validation Accuracy: 99.26%
#
# Epoch 23/30
# Training: 100%|██████████| 2188/2188 [03:57<00:00,  9.22it/s]
# Train Loss: 0.0152, Train Accuracy: 99.50%
# Validation: 100%|██████████| 469/469 [00:33<00:00, 13.89it/s]
# Validation Loss: 0.0186, Validation Accuracy: 99.47%
#
# Epoch 24/30
# Training: 100%|██████████| 2188/2188 [03:56<00:00,  9.25it/s]
# Train Loss: 0.0130, Train Accuracy: 99.57%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.70it/s]
# Validation Loss: 0.0289, Validation Accuracy: 99.29%
#
# Epoch 25/30
# Training: 100%|██████████| 2188/2188 [03:59<00:00,  9.14it/s]
# Train Loss: 0.0128, Train Accuracy: 99.61%
# Validation: 100%|██████████| 469/469 [00:35<00:00, 13.15it/s]
# Validation Loss: 0.0178, Validation Accuracy: 99.54%
#
# Epoch 26/30
# Training: 100%|██████████| 2188/2188 [04:01<00:00,  9.04it/s]
# Train Loss: 0.0162, Train Accuracy: 99.49%
# Validation: 100%|██████████| 469/469 [00:35<00:00, 13.26it/s]
# Validation Loss: 0.0277, Validation Accuracy: 99.19%
#
# Epoch 27/30
# Training: 100%|██████████| 2188/2188 [04:01<00:00,  9.05it/s]
# Train Loss: 0.0111, Train Accuracy: 99.63%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.58it/s]
# Validation Loss: 0.0198, Validation Accuracy: 99.47%
#
# Epoch 28/30
# Training: 100%|██████████| 2188/2188 [03:59<00:00,  9.15it/s]
# Train Loss: 0.0138, Train Accuracy: 99.57%
# Validation: 100%|██████████| 469/469 [00:35<00:00, 13.36it/s]
# Validation Loss: 0.0380, Validation Accuracy: 99.08%
#
# Epoch 29/30
# Training: 100%|██████████| 2188/2188 [04:00<00:00,  9.10it/s]
# Train Loss: 0.0121, Train Accuracy: 99.61%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.64it/s]
# Validation Loss: 0.0211, Validation Accuracy: 99.33%
#
# Epoch 30/30
# Training: 100%|██████████| 2188/2188 [04:00<00:00,  9.11it/s]
# Train Loss: 0.0118, Train Accuracy: 99.63%
# Validation: 100%|██████████| 469/469 [00:34<00:00, 13.65it/s]
# Validation Loss: 0.1033, Validation Accuracy: 98.99%

# %%
# Plot the metrics
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 5))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label="Train Accuracy")
plt.plot(epochs, val_accuracies, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
times = measure_inference_time(model, test_loader, device)

# %%
dummy_input = torch.randn(32, 3, 224, 224).cuda()

# Profiling inference
with profiler.profile(
    activities=[
       profiler.ProfilerActivity.CPU,
        profiler.ProfilerActivity.CUDA,  # Include if using GPU
    ],
    on_trace_ready=profiler.tensorboard_trace_handler("./logs"),  # Optional logging
    record_shapes=True,
    with_stack=True
) as prof:
    with torch.no_grad():
        model(dummy_input)


# Print results
print(prof.key_averages().table(sort_by="cuda_time_total" if torch.cuda.is_available() else "cpu_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::conv2d         0.74%     489.844us        17.36%      11.417ms     140.954us       0.000us         0.00%       3.932ms      48.540us            81
#                                       aten::convolution         0.74%     484.658us        16.61%      10.927ms     134.907us       0.000us         0.00%       3.932ms      48.540us            81
#                                      aten::_convolution         4.66%       3.066ms        15.88%      10.443ms     128.923us       0.000us         0.00%       3.932ms      48.540us            81
#                                        aten::batch_norm         0.35%     231.068us        73.49%      48.337ms     986.469us       0.000us         0.00%       3.782ms      77.191us            49
#                            aten::_batch_norm_impl_index         4.73%       3.112ms        73.14%      48.106ms     981.753us       0.000us         0.00%       3.782ms      77.191us            49
#                                  aten::cudnn_batch_norm        12.78%       8.405ms        68.40%      44.994ms     918.247us       3.782ms        38.33%       3.782ms      77.191us            49
# void cudnn::bn_fw_tr_1C11_kernel_NCHW<float, float, ...         0.00%       0.000us         0.00%       0.000us       0.000us       2.008ms        20.35%       2.008ms     501.889us             4
#                                 aten::cudnn_convolution         5.48%       3.602ms         9.10%       5.988ms      92.123us       1.976ms        20.02%       1.976ms      30.397us            65
#                                 aten::_conv_depthwise2d         0.38%     249.333us         0.93%     610.894us      38.181us       1.833ms        18.58%       1.833ms     114.590us            16
#                                             aten::silu_         1.02%     670.726us         1.72%       1.133ms      23.114us       1.039ms        10.53%       1.039ms      21.206us            49
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 65.776ms
# Self CUDA time total: 9.868ms

# %%
save_path = "EfficientNet_B0_NCT_CRC_HE.pth"
torch.save(model.state_dict(), save_path)
print(f"Model weights saved to {save_path}")
# Out:
# Model weights saved to EfficientNet_B0_NCT_CRC_HE.pth

# %%
def cv2_loader(path: str):
    return Image.fromarray(cv2.imread(path, -1)[:, :, ::-1])

# %%
test_dir = './test/CRC-VAL-HE-7K'

test_transforms = transforms.Compose([transforms.ToTensor()])
test_dataset = datasets.ImageFolder(test_dir, transform=test_transforms)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)
print(f"External Test set size: {len(test_dataset)}")
# Out:
# External Test set size: 7180

# %%
from sklearn.metrics import f1_score, recall_score, precision_score


def score_evaluate(model, data_loader, criterion, device, phase="Validation"):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    all_labels = []
    all_preds = []

    with torch.no_grad():
        for inputs, labels in tqdm(data_loader, desc=f"{phase}"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    overall_f1 = f1_score(all_labels, all_preds, average="macro")
    overall_recall = recall_score(all_labels, all_preds, average="macro")
    overall_precision = precision_score(all_labels, all_preds, average="macro")

    f1_per_class = f1_score(all_labels, all_preds, average=None)
    recall_per_class = recall_score(all_labels, all_preds, average=None)
    precision_per_class = precision_score(all_labels, all_preds, average=None)
    class_labels = sorted(set(all_labels))

    epoch_loss = running_loss / len(data_loader)
    accuracy = 100 * correct / total
    print(f"{phase} Loss: {epoch_loss:.4f}, {phase} Accuracy: {accuracy:.2f}%")
    val_losses.append(epoch_loss)
    val_accuracies.append(accuracy)

    print(f"Overall - F1: {overall_f1:.4f}, Recall: {overall_recall:.4f}, Precision: {overall_precision:.4f}")
    print("Per-Class Metrics:")
    for i, label in enumerate(class_labels):
        print(f"Class {label} - F1: {f1_per_class[i]:.4f}, Recall: {recall_per_class[i]:.4f}, Precision: {precision_per_class[i]:.4f}")

    return overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class

# %%
overall_f1, overall_recall, overall_precision, f1_per_class, recall_per_class, precision_per_class = score_evaluate(model, test_dataloader, criterion, device)
# Out:
# Validation: 100%|██████████| 225/225 [00:11<00:00, 19.74it/s]
# Validation Loss: 0.2720, Validation Accuracy: 93.89%
# Overall - F1: 0.9156, Recall: 0.9253, Precision: 0.9174
# Per-Class Metrics:
# Class 0 - F1: 0.9671, Recall: 0.9439, Precision: 0.9914
# Class 1 - F1: 0.9678, Recall: 0.9929, Precision: 0.9439
# Class 2 - F1: 0.8422, Recall: 1.0000, Precision: 0.7275
# Class 3 - F1: 0.9592, Recall: 1.0000, Precision: 0.9215
# Class 4 - F1: 0.9864, Recall: 0.9778, Precision: 0.9951
# Class 5 - F1: 0.8230, Recall: 0.8446, Precision: 0.8026
# Class 6 - F1: 0.9708, Recall: 0.9879, Precision: 0.9544
# Class 7 - F1: 0.7664, Recall: 0.6508, Precision: 0.9320
# Class 8 - F1: 0.9578, Recall: 0.9294, Precision: 0.9879

# %%
x = ["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", 'STR', "TUM"]
y = ["F1", "Precision", "Recall"]

f1_score_list = []
precision_score_list = []
recall_score_list = []

for i, class_name in enumerate(x):
    f1_score_list.append(f1_per_class[i])
    precision_score_list.append(precision_per_class[i])
    recall_score_list.append(recall_per_class[i])

x.append("Overall")
f1_score_list.append(overall_f1)
precision_score_list.append(overall_precision)
recall_score_list.append(overall_recall)

score_list = [f1_score_list, precision_score_list, recall_score_list]
score_list = np.array(score_list)
plt.figure(figsize=(20, 12))
score_cm = plt.matshow(score_list, cmap=plt.cm.Blues, alpha=0.3)
plt.xticks(range(len(x)), x)
plt.yticks(range(len(y)), y)
for i in range(len(y)):
    for j in range(len(x)):
        # 행렬의 각각의 수치를 각 칸의 중앙에 넣어준다
        plt.text(x=j, y=i,
                     s="{:.2f}".format(score_list[i, j]),
                     va='center',
                     ha='center',
                     )
